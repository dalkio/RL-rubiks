# %%
import numpy as np
import pandas as pd
import json
# %matplotlib qt
from rubiks_cube import RubiksCube, RubiksAction

# %%
rubiks_cube = RubiksCube(shuffle=True)
print('Is resolved: {0}'.format(rubiks_cube.is_resolved()))
# Out:
# Cube initialized!
# Is resolved: False

# %%
with open('example.json', 'r') as fp:
    example = json.load(fp)
rubiks_cube = RubiksCube(cube=np.asarray(example['cube']), verbose=True)
for action in example['actions']:
    step, reward, done, _ = rubiks_cube.step(RubiksAction(action))
print('Is resolved: ', done)
# Out:
# 1: Action(side='r', direction='d') done, reward=-1
# 2: Action(side='f', direction='i') done, reward=-1
# 3: Action(side='r', direction='d') done, reward=-1
# 4: Action(side='l', direction='d') done, reward=-1
# 5: Action(side='b', direction='i') done, reward=-1
# 6: Action(side='u', direction='d') done, reward=-1
# 7: Action(side='d', direction='i') done, reward=-1
# 8: Action(side='l', direction='d') done, reward=-1
# 9: Action(side='d', direction='d') done, reward=-1
# 10: Action(side='u', direction='d') done, reward=-1
# 11: Action(side='u', direction='d') done, reward=-1
# 12: Action(side='b', direction='i') done, reward=-1
# 13: Action(side='l', direction='i') done, reward=-1
# 14: Action(side='r', direction='d') done, reward=-1
# 15: Action(side='u', direction='d') done, reward=-1
# 16: Action(side='l', direction='d') done, reward=-1
# 17: Action(side='r', direction='i') done, reward=-1
# 18: Action(side='l', direction='i') done, reward=-1
# 19: Action(side='b', direction='i') done, reward=-1
# 20: Action(side='l', direction='d') done, reward=-1
# 21: Action(side='b', direction='i') done, reward=-1
# 22: Action(side='b', direction='i') done, reward=-1
# 23: Action(side='u', direction='i') done, reward=-1
# 24: Action(side='b', direction='d') done, reward=-1
# 25: Action(side='u', direction='d') done, reward=-1
# 26: Action(side='u', direction='d') done, reward=-1
# 27: Action(side='b', direction='i') done, reward=-1
# 28: Action(side='u', direction='i') done, reward=-1
# 29: Action(side='r', direction='i') done, reward=-1
# 30: Action(side='b', direction='i') done, reward=-1
# 31: Action(side='r', direction='d') done, reward=-1
# 32: Action(side='d', direction='i') done, reward=-1
# 33: Action(side='b', direction='i') done, reward=-1
# 34: Action(side='d', direction='d') done, reward=-1
# 35: Action(side='d', direction='i') done, reward=-1
# 36: Action(side='b', direction='i') done, reward=-1
# 37: Action(side='d', direction='d') done, reward=-1
# 38: Action(side='b', direction='d') done, reward=-1
# 39: Action(side='d', direction='i') done, reward=-1
# 40: Action(side='b', direction='i') done, reward=-1
# 41: Action(side='d', direction='d') done, reward=-1
# 42: Action(side='b', direction='i') done, reward=-1
# 43: Action(side='l', direction='i') done, reward=-1
# 44: Action(side='b', direction='d') done, reward=-1
# 45: Action(side='l', direction='d') done, reward=-1
# 46: Action(side='b', direction='d') done, reward=-1
# 47: Action(side='d', direction='d') done, reward=-1
# 48: Action(side='b', direction='i') done, reward=-1
# 49: Action(side='d', direction='i') done, reward=-1
# 50: Action(side='b', direction='i') done, reward=-1
# 51: Action(side='b', direction='d') done, reward=-1
# 52: Action(side='r', direction='d') done, reward=-1
# 53: Action(side='b', direction='i') done, reward=-1
# 54: Action(side='r', direction='i') done, reward=-1
# 55: Action(side='b', direction='i') done, reward=-1
# 56: Action(side='d', direction='i') done, reward=-1
# 57: Action(side='b', direction='d') done, reward=-1
# 58: Action(side='d', direction='d') done, reward=-1
# 59: Action(side='b', direction='d') done, reward=-1
# 60: Action(side='l', direction='d') done, reward=-1
# 61: Action(side='b', direction='i') done, reward=-1
# 62: Action(side='l', direction='i') done, reward=-1
# 63: Action(side='b', direction='i') done, reward=-1
# 64: Action(side='u', direction='i') done, reward=-1
# 65: Action(side='b', direction='d') done, reward=-1
# 66: Action(side='u', direction='d') done, reward=-1
# 67: Action(side='b', direction='d') done, reward=-1
# 68: Action(side='b', direction='i') done, reward=-1
# 69: Action(side='r', direction='i') done, reward=-1
# 70: Action(side='b', direction='d') done, reward=-1
# 71: Action(side='r', direction='d') done, reward=-1
# 72: Action(side='b', direction='d') done, reward=-1
# 73: Action(side='u', direction='d') done, reward=-1
# 74: Action(side='b', direction='i') done, reward=-1
# 75: Action(side='u', direction='i') done, reward=-1
# 76: Action(side='b', direction='i') done, reward=-1
# 77: Action(side='l', direction='i') done, reward=-1
# 78: Action(side='b', direction='d') done, reward=-1
# 79: Action(side='b', direction='d') done, reward=-1
# 80: Action(side='l', direction='d') done, reward=-1
# 81: Action(side='b', direction='d') done, reward=-1
# 82: Action(side='l', direction='i') done, reward=-1
# 83: Action(side='b', direction='d') done, reward=-1
# 84: Action(side='l', direction='d') done, reward=-1
# 85: Action(side='b', direction='d') done, reward=-1
# 86: Action(side='r', direction='d') done, reward=-1
# 87: Action(side='b', direction='i') done, reward=-1
# 88: Action(side='l', direction='i') done, reward=-1
# 89: Action(side='b', direction='d') done, reward=-1
# 90: Action(side='r', direction='i') done, reward=-1
# 91: Action(side='b', direction='i') done, reward=-1
# 92: Action(side='l', direction='d') done, reward=-1
# 93: Action(side='b', direction='d') done, reward=-1
# 94: Action(side='r', direction='d') done, reward=-1
# 95: Action(side='b', direction='i') done, reward=-1
# 96: Action(side='l', direction='i') done, reward=-1
# 97: Action(side='b', direction='d') done, reward=-1
# 98: Action(side='r', direction='i') done, reward=-1
# 99: Action(side='b', direction='i') done, reward=-1
# 100: Action(side='l', direction='d') done, reward=-1
# 101: Action(side='b', direction='d') done, reward=-1
# 102: Action(side='r', direction='i') done, reward=-1
# 103: Action(side='b', direction='d') done, reward=-1
# 104: Action(side='b', direction='d') done, reward=-1
# 105: Action(side='r', direction='d') done, reward=-1
# 106: Action(side='b', direction='d') done, reward=-1
# 107: Action(side='r', direction='i') done, reward=-1
# 108: Action(side='b', direction='d') done, reward=-1
# 109: Action(side='r', direction='d') done, reward=-1
# 110: Action(side='l', direction='d') done, reward=-1
# 111: Action(side='b', direction='i') done, reward=-1
# 112: Action(side='b', direction='i') done, reward=-1
# 113: Action(side='l', direction='i') done, reward=-1
# 114: Action(side='b', direction='i') done, reward=-1
# 115: Action(side='l', direction='d') done, reward=-1
# 116: Action(side='b', direction='i') done, reward=-1
# 117: Action(side='l', direction='i') done, reward=-1
# 118: Action(side='d', direction='i') done, reward=-1
# 119: Action(side='b', direction='d') done, reward=-1
# 120: Action(side='b', direction='d') done, reward=-1
# 121: Action(side='d', direction='d') done, reward=-1
# 122: Action(side='b', direction='d') done, reward=-1
# 123: Action(side='d', direction='i') done, reward=-1
# 124: Action(side='b', direction='d') done, reward=-1
# 125: Action(side='d', direction='d') done, reward=-1
# 126: Action(side='u', direction='d') done, reward=-1
# 127: Action(side='b', direction='i') done, reward=-1
# 128: Action(side='b', direction='i') done, reward=-1
# 129: Action(side='u', direction='i') done, reward=-1
# 130: Action(side='b', direction='i') done, reward=-1
# 131: Action(side='u', direction='d') done, reward=-1
# 132: Action(side='b', direction='i') done, reward=-1
# 133: Action(side='u', direction='i') done, reward=-1
# 134: Action(side='d', direction='i') done, reward=-1
# 135: Action(side='b', direction='d') done, reward=-1
# 136: Action(side='b', direction='d') done, reward=-1
# 137: Action(side='d', direction='d') done, reward=-1
# 138: Action(side='b', direction='d') done, reward=-1
# 139: Action(side='d', direction='i') done, reward=-1
# 140: Action(side='b', direction='d') done, reward=-1
# 141: Action(side='d', direction='d') done, reward=-1
# 142: Action(side='u', direction='d') done, reward=-1
# 143: Action(side='b', direction='i') done, reward=-1
# 144: Action(side='b', direction='i') done, reward=-1
# 145: Action(side='u', direction='i') done, reward=-1
# 146: Action(side='b', direction='i') done, reward=-1
# 147: Action(side='u', direction='d') done, reward=-1
# 148: Action(side='b', direction='i') done, reward=-1
# 149: Action(side='u', direction='i') done, reward=-1
# 150: Action(side='l', direction='i') done, reward=-1
# 151: Action(side='b', direction='d') done, reward=-1
# 152: Action(side='b', direction='d') done, reward=-1
# 153: Action(side='l', direction='d') done, reward=-1
# 154: Action(side='b', direction='d') done, reward=-1
# 155: Action(side='l', direction='i') done, reward=-1
# 156: Action(side='b', direction='d') done, reward=-1
# 157: Action(side='l', direction='d') done, reward=-1
# 158: Action(side='r', direction='d') done, reward=-1
# 159: Action(side='b', direction='i') done, reward=-1
# 160: Action(side='b', direction='i') done, reward=-1
# 161: Action(side='r', direction='i') done, reward=-1
# 162: Action(side='b', direction='i') done, reward=-1
# 163: Action(side='r', direction='d') done, reward=-1
# 164: Action(side='b', direction='i') done, reward=-1
# 165: Action(side='r', direction='i') done, reward=1
# Is resolved:  True

# %%
rubiks_cube.render()
