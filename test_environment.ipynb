# %%
import numpy as np
import pandas as pd
import json
# %matplotlib qt
from rubiks_cube import RubiksCube, RubiksAction

# %%
rubiks_cube = RubiksCube(shuffle=True)
print('Is resolved: {0}'.format(rubiks_cube.is_resolved()))
# Out:
# Cube initialized!
# Cube shuffled 100 times
# Is resolved: False

# %%
with open('example.json', 'r') as fp:
    example = json.load(fp)
rubiks_cube = RubiksCube(cube=np.asarray(example['cube']))
for action in example['actions']:
    reward, done = rubiks_cube.step(RubiksAction(action))
print('Is resolved: ', done)
# Out:
# 1: Action(side='r', direction='d') done, reward=13
# 2: Action(side='f', direction='i') done, reward=15
# 3: Action(side='r', direction='d') done, reward=17
# 4: Action(side='l', direction='d') done, reward=16
# 5: Action(side='b', direction='i') done, reward=15
# 6: Action(side='u', direction='d') done, reward=15
# 7: Action(side='d', direction='i') done, reward=15
# 8: Action(side='l', direction='d') done, reward=17
# 9: Action(side='d', direction='d') done, reward=16
# 10: Action(side='u', direction='d') done, reward=17
# 11: Action(side='u', direction='d') done, reward=16
# 12: Action(side='b', direction='i') done, reward=17
# 13: Action(side='l', direction='i') done, reward=15
# 14: Action(side='r', direction='d') done, reward=15
# 15: Action(side='u', direction='d') done, reward=16
# 16: Action(side='l', direction='d') done, reward=19
# 17: Action(side='r', direction='i') done, reward=23
# 18: Action(side='l', direction='i') done, reward=20
# 19: Action(side='b', direction='i') done, reward=21
# 20: Action(side='l', direction='d') done, reward=24
# 21: Action(side='b', direction='i') done, reward=23
# 22: Action(side='b', direction='i') done, reward=22
# 23: Action(side='u', direction='i') done, reward=23
# 24: Action(side='b', direction='d') done, reward=27
# 25: Action(side='u', direction='d') done, reward=28
# 26: Action(side='u', direction='d') done, reward=25
# 27: Action(side='b', direction='i') done, reward=27
# 28: Action(side='u', direction='i') done, reward=28
# 29: Action(side='r', direction='i') done, reward=25
# 30: Action(side='b', direction='i') done, reward=26
# 31: Action(side='r', direction='d') done, reward=31
# 32: Action(side='d', direction='i') done, reward=27
# 33: Action(side='b', direction='i') done, reward=26
# 34: Action(side='d', direction='d') done, reward=29
# 35: Action(side='d', direction='i') done, reward=26
# 36: Action(side='b', direction='i') done, reward=25
# 37: Action(side='d', direction='d') done, reward=26
# 38: Action(side='b', direction='d') done, reward=29
# 39: Action(side='d', direction='i') done, reward=27
# 40: Action(side='b', direction='i') done, reward=27
# 41: Action(side='d', direction='d') done, reward=32
# 42: Action(side='b', direction='i') done, reward=32
# 43: Action(side='l', direction='i') done, reward=29
# 44: Action(side='b', direction='d') done, reward=29
# 45: Action(side='l', direction='d') done, reward=33
# 46: Action(side='b', direction='d') done, reward=28
# 47: Action(side='d', direction='d') done, reward=23
# 48: Action(side='b', direction='i') done, reward=28
# 49: Action(side='d', direction='i') done, reward=36
# 50: Action(side='b', direction='i') done, reward=33
# 51: Action(side='b', direction='d') done, reward=36
# 52: Action(side='r', direction='d') done, reward=28
# 53: Action(side='b', direction='i') done, reward=27
# 54: Action(side='r', direction='i') done, reward=33
# 55: Action(side='b', direction='i') done, reward=29
# 56: Action(side='d', direction='i') done, reward=26
# 57: Action(side='b', direction='d') done, reward=29
# 58: Action(side='d', direction='d') done, reward=36
# 59: Action(side='b', direction='d') done, reward=32
# 60: Action(side='l', direction='d') done, reward=28
# 61: Action(side='b', direction='i') done, reward=31
# 62: Action(side='l', direction='i') done, reward=36
# 63: Action(side='b', direction='i') done, reward=32
# 64: Action(side='u', direction='i') done, reward=29
# 65: Action(side='b', direction='d') done, reward=32
# 66: Action(side='u', direction='d') done, reward=38
# 67: Action(side='b', direction='d') done, reward=36
# 68: Action(side='b', direction='i') done, reward=38
# 69: Action(side='r', direction='i') done, reward=31
# 70: Action(side='b', direction='d') done, reward=30
# 71: Action(side='r', direction='d') done, reward=36
# 72: Action(side='b', direction='d') done, reward=33
# 73: Action(side='u', direction='d') done, reward=28
# 74: Action(side='b', direction='i') done, reward=34
# 75: Action(side='u', direction='i') done, reward=41
# 76: Action(side='b', direction='i') done, reward=41
# 77: Action(side='l', direction='i') done, reward=35
# 78: Action(side='b', direction='d') done, reward=32
# 79: Action(side='b', direction='d') done, reward=29
# 80: Action(side='l', direction='d') done, reward=34
# 81: Action(side='b', direction='d') done, reward=34
# 82: Action(side='l', direction='i') done, reward=28
# 83: Action(side='b', direction='d') done, reward=32
# 84: Action(side='l', direction='d') done, reward=42
# 85: Action(side='b', direction='d') done, reward=44
# 86: Action(side='r', direction='d') done, reward=36
# 87: Action(side='b', direction='i') done, reward=34
# 88: Action(side='l', direction='i') done, reward=23
# 89: Action(side='b', direction='d') done, reward=24
# 90: Action(side='r', direction='i') done, reward=33
# 91: Action(side='b', direction='i') done, reward=33
# 92: Action(side='l', direction='d') done, reward=42
# 93: Action(side='b', direction='d') done, reward=43
# 94: Action(side='r', direction='d') done, reward=34
# 95: Action(side='b', direction='i') done, reward=30
# 96: Action(side='l', direction='i') done, reward=24
# 97: Action(side='b', direction='d') done, reward=25
# 98: Action(side='r', direction='i') done, reward=33
# 99: Action(side='b', direction='i') done, reward=35
# 100: Action(side='l', direction='d') done, reward=40
# 101: Action(side='b', direction='d') done, reward=42
# 102: Action(side='r', direction='i') done, reward=34
# 103: Action(side='b', direction='d') done, reward=29
# 104: Action(side='b', direction='d') done, reward=30
# 105: Action(side='r', direction='d') done, reward=35
# 106: Action(side='b', direction='d') done, reward=33
# 107: Action(side='r', direction='i') done, reward=30
# 108: Action(side='b', direction='d') done, reward=33
# 109: Action(side='r', direction='d') done, reward=40
# 110: Action(side='l', direction='d') done, reward=32
# 111: Action(side='b', direction='i') done, reward=33
# 112: Action(side='b', direction='i') done, reward=29
# 113: Action(side='l', direction='i') done, reward=34
# 114: Action(side='b', direction='i') done, reward=35
# 115: Action(side='l', direction='d') done, reward=30
# 116: Action(side='b', direction='i') done, reward=37
# 117: Action(side='l', direction='i') done, reward=45
# 118: Action(side='d', direction='i') done, reward=39
# 119: Action(side='b', direction='d') done, reward=32
# 120: Action(side='b', direction='d') done, reward=32
# 121: Action(side='d', direction='d') done, reward=34
# 122: Action(side='b', direction='d') done, reward=35
# 123: Action(side='d', direction='i') done, reward=29
# 124: Action(side='b', direction='d') done, reward=32
# 125: Action(side='d', direction='d') done, reward=39
# 126: Action(side='u', direction='d') done, reward=32
# 127: Action(side='b', direction='i') done, reward=29
# 128: Action(side='b', direction='i') done, reward=28
# 129: Action(side='u', direction='i') done, reward=33
# 130: Action(side='b', direction='i') done, reward=35
# 131: Action(side='u', direction='d') done, reward=31
# 132: Action(side='b', direction='i') done, reward=38
# 133: Action(side='u', direction='i') done, reward=48
# 134: Action(side='d', direction='i') done, reward=38
# 135: Action(side='b', direction='d') done, reward=31
# 136: Action(side='b', direction='d') done, reward=32
# 137: Action(side='d', direction='d') done, reward=37
# 138: Action(side='b', direction='d') done, reward=33
# 139: Action(side='d', direction='i') done, reward=30
# 140: Action(side='b', direction='d') done, reward=34
# 141: Action(side='d', direction='d') done, reward=41
# 142: Action(side='u', direction='d') done, reward=31
# 143: Action(side='b', direction='i') done, reward=29
# 144: Action(side='b', direction='i') done, reward=29
# 145: Action(side='u', direction='i') done, reward=35
# 146: Action(side='b', direction='i') done, reward=35
# 147: Action(side='u', direction='d') done, reward=31
# 148: Action(side='b', direction='i') done, reward=38
# 149: Action(side='u', direction='i') done, reward=48
# 150: Action(side='l', direction='i') done, reward=41
# 151: Action(side='b', direction='d') done, reward=32
# 152: Action(side='b', direction='d') done, reward=33
# 153: Action(side='l', direction='d') done, reward=34
# 154: Action(side='b', direction='d') done, reward=32
# 155: Action(side='l', direction='i') done, reward=30
# 156: Action(side='b', direction='d') done, reward=33
# 157: Action(side='l', direction='d') done, reward=40
# 158: Action(side='r', direction='d') done, reward=32
# 159: Action(side='b', direction='i') done, reward=28
# 160: Action(side='b', direction='i') done, reward=28
# 161: Action(side='r', direction='i') done, reward=35
# 162: Action(side='b', direction='i') done, reward=38
# 163: Action(side='r', direction='d') done, reward=32
# 164: Action(side='b', direction='i') done, reward=42
# 165: Action(side='r', direction='i') done, reward=54
# Is resolved:  True

# %%
rubiks_cube.render()
