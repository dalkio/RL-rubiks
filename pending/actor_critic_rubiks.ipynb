# %%
# -*- coding: utf-8 -*-
# <nbformat>4</nbformat>
import torch
import torch.nn as nn
from torch.autograd import Variable
import torch.optim as optim
from torch.distributions import Categorical
import numpy as np
import gym
from rubiks_cube import RubiksCube, RubiksAction

# %%
class Actor(nn.Module):
    def __init__(self, state_space_dim, action_space_dim,
                 actor_lr=0.01):
        """
        Actor agent. This is the agent that outputs a probability distribution over actions
        for a given input state
        :param env: The environment the agent will try to solve.
        :return: The instantiated Actor agent object.
        """
        super().__init__()
        self.action_space_dim = action_space_dim
        self.state_space_dim = state_space_dim
        self.lin1 = nn.Linear(self.state_space_dim, 24, bias=False)
        self.lin2 = nn.Linear(24, self.action_space_dim, bias=False)     
        self.optimizer = optim.Adam(self.parameters(), lr=actor_lr)
        
    def forward(self, x):
        """
        forward computation pass. Perform forward computation from input to output
        :param x: the state input.
        :return: The computed vector output of shape (self.state_space_dim,1).
        """
        x = self.lin1(x)
        x = self.lin2(x)
        x = nn.Softmax()(x)
        return x
    
    def update_actor(self, 
                 prev_rewards, 
                 prev_logs_probs, 
                 values_critic, 
                 terminal_state=False):
        """
        the update_actor function. This is the function that updates the weights of the actor
        agent so as to raise the probability to pick up actions that will improve, on average,
        the current expected cumulated reward with respect to the current policy i.e 
        the current probability distribution over actions 
        :param prev_rewards: torch.Tensor of shape (episode_length, 1), rewards cumulated over the episode.
        :param values_critic: list of torch.Tensor, expected cumulated rewards with respect to the states encountered during the episode, under the current critic agent.
        :param terminal_state (default: False): boolean, says if last cumulated state is terminal or not.
        :return: Nothing. Update of the actor's weights is done inplace.
        """
        sa_value_samples = []
        discount_factor = 0.9
        vfn_last = 0 if terminal_state else float(values_critic[-1])
        sa_value_sample = vfn_last
        # Discount future rewards back to the present using discount_factor
        discountable_rewards = reversed(list(prev_rewards[:-1]))
        for reward in discountable_rewards:
            sa_value_sample = reward + discount_factor * sa_value_sample
            sa_value_samples.append(sa_value_sample)
        sa_value_samples = sa_value_samples[::-1]
        sa_value_samples = torch.FloatTensor(sa_value_samples)
        
        values_critic = torch.cat(values_critic[:-1])
        prev_logs_probs = torch.cat(list(prev_logs_probs[:-1]))
        assert len(sa_value_samples) == len(values_critic) == len(prev_logs_probs)
        advantages = Variable(sa_value_samples) - values_critic
        loss = prev_logs_probs * advantages
        loss = sum(loss)*-1

        self.optimizer.zero_grad()
        loss.backward(retain_graph=True)
        self.optimizer.step()

class Critic(nn.Module):
    def __init__(self, state_space_dim, action_space_dim,
                 critic_lr=0.01):
        """
        Critic agent. This is the agent that outputs a scalar reprensenting the expected cumulated reward
        with respect to the input state and the current policy. To be combined with the Actor agent.
        :param env: The environment the agent will try to solve.
        :return: The instantiated Critic agent object.
        """
        super().__init__()
        self.state_space_dim = state_space_dim
        self.lin1 = nn.Linear(self.state_space_dim, 24, bias=False)
        self.lin2 = nn.Linear(24, 1, bias=False)
        self.optimizer = optim.Adam(self.parameters(), lr=critic_lr)
    
    def forward(self, x):
        """
        Forward computation pass. Perform forward computation from input to output.
        :param x: the state input.
        :return: The computed vector output.
        """
        x = self.lin1(x)
        x = nn.ReLU()(x)
        x = self.lin2(x)
        return x

    def update_critic(self,
                 prev_rewards,
                 values_critic,
                 terminal_state=False):
        """
        the update_critic function. This is the function that updates the weights of the critic agent so as
        to reduce the distance between predicted expected rewards under current policy and actually observed
        cumulated rewards under current policy for a given state.
        :param prev_rewards: torch.Tensor of shape (episode_length, 1), rewards cumulated over the episode.
        : param prev_logs_probs: torch.Tensor of shape (episode_length, 1), logarithm over probabilities of picked-up actions over the episode.
        :param values_critic: list of torch.Tensor, expected cumulated rewards with respect to the states encountered during the episode, under the current critic agent.
        :param terminal_state (default: False): boolean, says if last cumulated state is terminal or not.
        :return: Nothing. Update of the actor's weights is done inplace.
        """
        if len(prev_rewards) != len(values_critic):
            excep_msg = 'prev_rewards len : {} and values_critic len'
            excep_msg += ': {} should be equal : {} != {}'
            len1, len2 = len(prev_rewards), len(values_critic)
            raise Exception(excep_msg.format(l1,l2,l1,l2))
        better_values = []
        discount_factor = 0.9
        better_value_last =  0 if terminal_state else values_critic[-1]
        better_value = float(better_value_last)
        # Discount future rewards back to the present using discount_factor
        discountable_rewards = reversed(list(prev_rewards[:-1]))
        for reward in discountable_rewards:
            better_value = reward + discount_factor * better_value
            better_values.append(better_value)
        better_values = better_values[::-1]
        better_values = torch.FloatTensor(better_values)
        
        values_critic = torch.cat(values_critic[:-1])
        assert len(better_values) == len(values_critic)
        loss = (Variable(better_values) - values_critic) ** 2
        loss = sum(loss)
    
        self.optimizer.zero_grad()
        loss.backward(retain_graph=True)
        self.optimizer.step()

        
        
class AC(nn.Module):
    # not usual actor critic, advantage actor critic
    def __init__(self, state_space_dim, action_space_dim,
                 actor_lr=0.01, critic_lr=0.01):
        super().__init__()
        self.prev_rewards = None
        self.prev_logs_probs = None
        self.prev_states = None
        self.critic = Critic(state_space_dim, action_space_dim,
                             critic_lr=critic_lr)
        self.actor = Actor(state_space_dim, action_space_dim,
                           actor_lr=actor_lr)
        
    def get_action(self, current_state):
        """
        get_action function. From current probability distribution under the policy, samples a 
        possible action and computes logarithm over probability of sampled action.
        pytorch maintains a dynamic graph over computations involving to torch.Variable type variables. 
        Thus it will know how to backpropagate the gradient to the parameters involved in the making
        of the log values.
        :param current_state: torch.FloatTensor, the input state.
        :return: sampled_action, torch.autograd.variable.Variable, the action sampled.
        :return: log_prob_action, torch.autograd.variable.Variable, logarithm over sampled action's proba.
        """
        probability_distrib_actions = self.actor.forward(Variable(current_state))
        c = Categorical(probability_distrib_actions)
        sampled_action = c.sample()
        log_prob_action = c.log_prob(sampled_action)
        return sampled_action, log_prob_action
    
    def remember_logs_probs(self, log_prob):
        """
        Remember_logs_probs function. Adds an element to the list of logarithms over probabilities
        of past sampled actions.
        :param log_prob: a logarithm over probability of a sampled action.
        :return: Nothing, Update of the list of logarithms over probas is done inplace.
        """
        if self.prev_logs_probs is None:
            self.prev_logs_probs = log_prob
        else:
            self.prev_logs_probs = torch.cat([self.prev_logs_probs, log_prob])
            
    def forget_logs_probs(self):
        """
        forget_logs_probs function. deletes the list of logarithms over probabilities of past sampled actions.
        :param : Nothing. Deletion is done inplace.
        :return: Nothing. Deletion is done inplace.
        """
        self.prev_logs_probs = None
    
    def remember_rewards(self, reward):
        """
        remember_rewards function. Adds an element to the list of rewards from interactions with the environment.
        :param reward: float, a reward value.
        :return: Nothing, Update of the list of rewards is done inplace.
        """
        reward = torch.Tensor([float(reward)]) if not isinstance(reward, torch.Tensor) else reward
        if self.prev_rewards is None:
            self.prev_rewards = reward
        else:
            self.prev_rewards = torch.cat([self.prev_rewards, reward])
            
    def forget_rewards(self):
        """
        forget_rewards function. deletes the maintained list of rewards.
        :param : Nothing. Deletion is done inplace.
        :return: Nothing. Deletion is done inplace.
        """
        self.prev_rewards = None
    
    def remember_states(self, state):
        """
        remember_states function. Adds an element to the list of states gotten from interacting with the environment.
        :param state: torch.FloatTensor, the input state.
        :return: Nothing, Update of the list of states is done inplace
        """
        self.prev_states = [state] if self.prev_states is None \
            else self.prev_states + [state]
            
    def forget_states(self):
        """
        forget_states function. Deletes the maintained list of states.
        :param : Nothing. Deletion is done inplace.
        :return: Nothing. Deletion is done inplace.
        """
        self.prev_states = None
    
    def train(self, terminal_state):
        """
        Train the actor_critic agent. Trains first the actor agent and then the critic agent. Then forgets
        about rewars, states and logarithms over probabilities used for training.
        :param terminal_state: boolean, says if last cumulated state is terminal or not.
        :return: Nothing, Training is done inplace.
        """
        values_critic = [self.critic.forward(Variable(state)) for state in self.prev_states]
        self.actor.update_actor(self.prev_rewards, 
                            self.prev_logs_probs, 
                            values_critic,
                            terminal_state=terminal_state)
        self.critic.update_critic(self.prev_rewards, 
                             values_critic,
                             terminal_state=terminal_state)
        self.forget_logs_probs()
        self.forget_rewards()
        self.forget_states()

# %%
def run_rl(actor_critic, actions, rubiks_cube,
           nb_episodes=10_000, max_length_episode=100):
    """
    run_rl function. Function used to run the environment. Iterates episodes, a training session
    is triggered everytime an episode has ended. Cumulated reward over each episode is computed.
    A running reward of cumulated rewards over episodes is computed and trigger solved environment
    warning message when goes over a particular thresold.
    :param actor_critic: AC object, actor critic agent used to solve the environment.
    :param nb_episodes: int, max number of episodes to train on.
    :return: Nothing, running is done inplace.
    """
    nb_steps_before_remember = 10  # This variable is never used --> see commented line below unsure if keep it
    for episode in range(nb_episodes):
        cumul_reward = 0
        rubiks_cube = RubiksCube(shuffle=True)
        initial_state = rubiks_cube.cube.reshape(-1)
        done = False
        current_state = torch.from_numpy(initial_state).type(torch.FloatTensor)
        
        for step in range(1, max_length_episode):
            sampled_action, log_prob_action = actor_critic.get_action(current_state)
            reward, done = rubiks_cube.step(RubiksAction(actions[int(sampled_action)]))
            state = rubiks_cube.cube.reshape(-1)
            actor_critic.remember_logs_probs(log_prob_action)
            actor_critic.remember_rewards(reward)
            actor_critic.remember_states(current_state)
            current_state = torch.from_numpy(state).type(torch.FloatTensor)
            print("Episode : {} | Step : {} | Reward : {}".format(episode, step, reward))
            if done:
                if len(actor_critic.prev_rewards) <= 1:
                    pass
                else:
                    actor_critic.train(done)#send terminal state
                break

# %%
if __name__ == '__main__':
    sides = ['r', 'l', 'u', 'd', 'f', 'b']
    directions = ['d', 'i']
    actions = []
    for side in sides:
        for dir in directions:
            actions.append(side+dir)
            
    rubiks_cube = RubiksCube(shuffle=True)
    print('Is resolved: {0}'.format(rubiks_cube.is_resolved()))
    
    input_state_dim = int(np.prod(np.array(rubiks_cube.cube.shape)))
    actor_critic = AC(input_state_dim, len(actions), 
                      actor_lr=0.01, critic_lr=0.01)
    run_rl(actor_critic, actions, rubiks_cube, 
           nb_episodes=100, max_length_episode=100)
# Out:
# Cube initialized!
# Is resolved: False
# Cube initialized!
# Episode : 0 | Step : 1 | Reward : 13
# Episode : 0 | Step : 2 | Reward : 14
# Episode : 0 | Step : 3 | Reward : 14
# Episode : 0 | Step : 4 | Reward : 14
# Episode : 0 | Step : 5 | Reward : 14
# Episode : 0 | Step : 6 | Reward : 13
# Episode : 0 | Step : 7 | Reward : 18
# Episode : 0 | Step : 8 | Reward : 15
# Episode : 0 | Step : 9 | Reward : 14
# Episode : 0 | Step : 10 | Reward : 17
# Episode : 0 | Step : 11 | Reward : 17
# Episode : 0 | Step : 12 | Reward : 17
# Episode : 0 | Step : 13 | Reward : 14
# Episode : 0 | Step : 14 | Reward : 15
# Episode : 0 | Step : 15 | Reward : 16
# Episode : 0 | Step : 16 | Reward : 17
# Episode : 0 | Step : 17 | Reward : 16
# Episode : 0 | Step : 18 | Reward : 15
# Episode : 0 | Step : 19 | Reward : 13
# Episode : 0 | Step : 20 | Reward : 11
# Episode : 0 | Step : 21 | Reward : 11
# Episode : 0 | Step : 22 | Reward : 11
# Episode : 0 | Step : 23 | Reward : 13
# Episode : 0 | Step : 24 | Reward : 11
# Episode : 0 | Step : 25 | Reward : 13
# Episode : 0 | Step : 26 | Reward : 13
# Episode : 0 | Step : 27 | Reward : 12
# Episode : 0 | Step : 28 | Reward : 11
# Episode : 0 | Step : 29 | Reward : 10
# Episode : 0 | Step : 30 | Reward : 12
# Episode : 0 | Step : 31 | Reward : 14
# Episode : 0 | Step : 32 | Reward : 15
# Episode : 0 | Step : 33 | Reward : 15
# Episode : 0 | Step : 34 | Reward : 16
# Episode : 0 | Step : 35 | Reward : 16
# Episode : 0 | Step : 36 | Reward : 15
# Episode : 0 | Step : 37 | Reward : 14
# Episode : 0 | Step : 38 | Reward : 12
# Episode : 0 | Step : 39 | Reward : 12
# Episode : 0 | Step : 40 | Reward : 12
# Episode : 0 | Step : 41 | Reward : 12
# Episode : 0 | Step : 42 | Reward : 12
# Episode : 0 | Step : 43 | Reward : 15
# Episode : 0 | Step : 44 | Reward : 16
# Episode : 0 | Step : 45 | Reward : 17
# Episode : 0 | Step : 46 | Reward : 15
# Episode : 0 | Step : 47 | Reward : 17
# Episode : 0 | Step : 48 | Reward : 14
# Episode : 0 | Step : 49 | Reward : 13
# Episode : 0 | Step : 50 | Reward : 12
# Episode : 0 | Step : 51 | Reward : 13
# Episode : 0 | Step : 52 | Reward : 14
# Episode : 0 | Step : 53 | Reward : 16
# Episode : 0 | Step : 54 | Reward : 15
# Episode : 0 | Step : 55 | Reward : 16
# Episode : 0 | Step : 56 | Reward : 17
# Episode : 0 | Step : 57 | Reward : 16
# Episode : 0 | Step : 58 | Reward : 15
# Episode : 0 | Step : 59 | Reward : 13
# Episode : 0 | Step : 60 | Reward : 14
# Episode : 0 | Step : 61 | Reward : 12
# Episode : 0 | Step : 62 | Reward : 11
# Episode : 0 | Step : 63 | Reward : 12
# Episode : 0 | Step : 64 | Reward : 10
# Episode : 0 | Step : 65 | Reward : 11
# Episode : 0 | Step : 66 | Reward : 13
# Episode : 0 | Step : 67 | Reward : 12
# Episode : 0 | Step : 68 | Reward : 11
# Episode : 0 | Step : 69 | Reward : 12
# Episode : 0 | Step : 70 | Reward : 12
# Episode : 0 | Step : 71 | Reward : 12
# Episode : 0 | Step : 72 | Reward : 14
# Episode : 0 | Step : 73 | Reward : 12
# Episode : 0 | Step : 74 | Reward : 12
# Episode : 0 | Step : 75 | Reward : 15
# Episode : 0 | Step : 76 | Reward : 13
# Episode : 0 | Step : 77 | Reward : 15
# Episode : 0 | Step : 78 | Reward : 13
# Episode : 0 | Step : 79 | Reward : 15
# Episode : 0 | Step : 80 | Reward : 17
# Episode : 0 | Step : 81 | Reward : 14
# Episode : 0 | Step : 82 | Reward : 15
# Episode : 0 | Step : 83 | Reward : 16
# Episode : 0 | Step : 84 | Reward : 12
# Episode : 0 | Step : 85 | Reward : 11
# Episode : 0 | Step : 86 | Reward : 10
# Episode : 0 | Step : 87 | Reward : 9
# Episode : 0 | Step : 88 | Reward : 10
# Episode : 0 | Step : 89 | Reward : 13
# Episode : 0 | Step : 90 | Reward : 14
# Episode : 0 | Step : 91 | Reward : 15
# Episode : 0 | Step : 92 | Reward : 16
# Episode : 0 | Step : 93 | Reward : 17
# Episode : 0 | Step : 94 | Reward : 15
# Episode : 0 | Step : 95 | Reward : 11
# Episode : 0 | Step : 96 | Reward : 16
# Episode : 0 | Step : 97 | Reward : 13
# Episode : 0 | Step : 98 | Reward : 15
# Episode : 0 | Step : 99 | Reward : 13
# Cube initialized!
# /Users/guillaumeligner/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:25: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
# Episode : 1 | Step : 1 | Reward : 15
# Episode : 1 | Step : 2 | Reward : 17
# Episode : 1 | Step : 3 | Reward : 15
# Episode : 1 | Step : 4 | Reward : 13
# Episode : 1 | Step : 5 | Reward : 10
# Episode : 1 | Step : 6 | Reward : 11
# Episode : 1 | Step : 7 | Reward : 12
# Episode : 1 | Step : 8 | Reward : 13
# Episode : 1 | Step : 9 | Reward : 13
# Episode : 1 | Step : 10 | Reward : 14
# Episode : 1 | Step : 11 | Reward : 12
# Episode : 1 | Step : 12 | Reward : 11
# Episode : 1 | Step : 13 | Reward : 13
# Episode : 1 | Step : 14 | Reward : 11
# Episode : 1 | Step : 15 | Reward : 13
# Episode : 1 | Step : 16 | Reward : 12
# Episode : 1 | Step : 17 | Reward : 12
# Episode : 1 | Step : 18 | Reward : 12
# Episode : 1 | Step : 19 | Reward : 13
# Episode : 1 | Step : 20 | Reward : 17
# Episode : 1 | Step : 21 | Reward : 17
# Episode : 1 | Step : 22 | Reward : 16
# Episode : 1 | Step : 23 | Reward : 14
# Episode : 1 | Step : 24 | Reward : 19
# Episode : 1 | Step : 25 | Reward : 18
# Episode : 1 | Step : 26 | Reward : 15
# Episode : 1 | Step : 27 | Reward : 15
# Episode : 1 | Step : 28 | Reward : 15
# Episode : 1 | Step : 29 | Reward : 15
# Episode : 1 | Step : 30 | Reward : 14
# Episode : 1 | Step : 31 | Reward : 13
# Episode : 1 | Step : 32 | Reward : 17
# Episode : 1 | Step : 33 | Reward : 16
# Episode : 1 | Step : 34 | Reward : 17
# Episode : 1 | Step : 35 | Reward : 21
# Episode : 1 | Step : 36 | Reward : 16
# Episode : 1 | Step : 37 | Reward : 15
# Episode : 1 | Step : 38 | Reward : 18
# Episode : 1 | Step : 39 | Reward : 20
# Episode : 1 | Step : 40 | Reward : 17
# Episode : 1 | Step : 41 | Reward : 15
# Episode : 1 | Step : 42 | Reward : 17
# Episode : 1 | Step : 43 | Reward : 14
# Episode : 1 | Step : 44 | Reward : 14
# Episode : 1 | Step : 45 | Reward : 17
# Episode : 1 | Step : 46 | Reward : 14
# Episode : 1 | Step : 47 | Reward : 13
# Episode : 1 | Step : 48 | Reward : 16
# Episode : 1 | Step : 49 | Reward : 20
# Episode : 1 | Step : 50 | Reward : 23
# Episode : 1 | Step : 51 | Reward : 20
# Episode : 1 | Step : 52 | Reward : 18
# Episode : 1 | Step : 53 | Reward : 22
# Episode : 1 | Step : 54 | Reward : 19
# Episode : 1 | Step : 55 | Reward : 18
# Episode : 1 | Step : 56 | Reward : 21
# Episode : 1 | Step : 57 | Reward : 14
# Episode : 1 | Step : 58 | Reward : 15
# Episode : 1 | Step : 59 | Reward : 13
# Episode : 1 | Step : 60 | Reward : 12
# Episode : 1 | Step : 61 | Reward : 12
# Episode : 1 | Step : 62 | Reward : 12
# Episode : 1 | Step : 63 | Reward : 14
# Episode : 1 | Step : 64 | Reward : 15
# Episode : 1 | Step : 65 | Reward : 14
# Episode : 1 | Step : 66 | Reward : 12
# Episode : 1 | Step : 67 | Reward : 10
# Episode : 1 | Step : 68 | Reward : 12
# Episode : 1 | Step : 69 | Reward : 13
# Episode : 1 | Step : 70 | Reward : 11
# Episode : 1 | Step : 71 | Reward : 12
# Episode : 1 | Step : 72 | Reward : 12
# Episode : 1 | Step : 73 | Reward : 13
# Episode : 1 | Step : 74 | Reward : 12
# Episode : 1 | Step : 75 | Reward : 15
# Episode : 1 | Step : 76 | Reward : 18
# Episode : 1 | Step : 77 | Reward : 18
# Episode : 1 | Step : 78 | Reward : 20
# Episode : 1 | Step : 79 | Reward : 17
# Episode : 1 | Step : 80 | Reward : 15
# Episode : 1 | Step : 81 | Reward : 14
# Episode : 1 | Step : 82 | Reward : 14
# Episode : 1 | Step : 83 | Reward : 15
# Episode : 1 | Step : 84 | Reward : 14
# Episode : 1 | Step : 85 | Reward : 16
# Episode : 1 | Step : 86 | Reward : 14
# Episode : 1 | Step : 87 | Reward : 16
# Episode : 1 | Step : 88 | Reward : 16
# Episode : 1 | Step : 89 | Reward : 16
# Episode : 1 | Step : 90 | Reward : 13
# Episode : 1 | Step : 91 | Reward : 13
# Episode : 1 | Step : 92 | Reward : 10
# Episode : 1 | Step : 93 | Reward : 13
# Episode : 1 | Step : 94 | Reward : 17
# Episode : 1 | Step : 95 | Reward : 16
# Episode : 1 | Step : 96 | Reward : 17
# Episode : 1 | Step : 97 | Reward : 13
# Episode : 1 | Step : 98 | Reward : 10
# Episode : 1 | Step : 99 | Reward : 12
# Cube initialized!
# Episode : 2 | Step : 1 | Reward : 16
# Episode : 2 | Step : 2 | Reward : 19
# Episode : 2 | Step : 3 | Reward : 15
# Episode : 2 | Step : 4 | Reward : 15
# Episode : 2 | Step : 5 | Reward : 15
# Episode : 2 | Step : 6 | Reward : 14
# Episode : 2 | Step : 7 | Reward : 15
# Episode : 2 | Step : 8 | Reward : 11
# Episode : 2 | Step : 9 | Reward : 12
# Episode : 2 | Step : 10 | Reward : 14
# Episode : 2 | Step : 11 | Reward : 15
# Episode : 2 | Step : 12 | Reward : 14
# Episode : 2 | Step : 13 | Reward : 14
# Episode : 2 | Step : 14 | Reward : 13
# Episode : 2 | Step : 15 | Reward : 14
# Episode : 2 | Step : 16 | Reward : 15
# Episode : 2 | Step : 17 | Reward : 19
# Episode : 2 | Step : 18 | Reward : 18
# Episode : 2 | Step : 19 | Reward : 15
# Episode : 2 | Step : 20 | Reward : 16
# Episode : 2 | Step : 21 | Reward : 12
# Episode : 2 | Step : 22 | Reward : 16
# Episode : 2 | Step : 23 | Reward : 16
# Episode : 2 | Step : 24 | Reward : 12
# Episode : 2 | Step : 25 | Reward : 13
# Episode : 2 | Step : 26 | Reward : 12
# Episode : 2 | Step : 27 | Reward : 12
# Episode : 2 | Step : 28 | Reward : 12
# Episode : 2 | Step : 29 | Reward : 12
# Episode : 2 | Step : 30 | Reward : 12
# Episode : 2 | Step : 31 | Reward : 10
# Episode : 2 | Step : 32 | Reward : 12
# Episode : 2 | Step : 33 | Reward : 11
# Episode : 2 | Step : 34 | Reward : 9
# Episode : 2 | Step : 35 | Reward : 9
# Episode : 2 | Step : 36 | Reward : 12
# Episode : 2 | Step : 37 | Reward : 17
# Episode : 2 | Step : 38 | Reward : 20
# Episode : 2 | Step : 39 | Reward : 17
# Episode : 2 | Step : 40 | Reward : 16
# Episode : 2 | Step : 41 | Reward : 15
# Episode : 2 | Step : 42 | Reward : 15
# Episode : 2 | Step : 43 | Reward : 15
# Episode : 2 | Step : 44 | Reward : 13
# Episode : 2 | Step : 45 | Reward : 11
# Episode : 2 | Step : 46 | Reward : 13
# Episode : 2 | Step : 47 | Reward : 15
# Episode : 2 | Step : 48 | Reward : 14
# Episode : 2 | Step : 49 | Reward : 14
# Episode : 2 | Step : 50 | Reward : 12
# Episode : 2 | Step : 51 | Reward : 15
# Episode : 2 | Step : 52 | Reward : 19
# Episode : 2 | Step : 53 | Reward : 16
# Episode : 2 | Step : 54 | Reward : 16
# Episode : 2 | Step : 55 | Reward : 14
# Episode : 2 | Step : 56 | Reward : 13
# Episode : 2 | Step : 57 | Reward : 16
# Episode : 2 | Step : 58 | Reward : 12
# Episode : 2 | Step : 59 | Reward : 13
# Episode : 2 | Step : 60 | Reward : 12
# Episode : 2 | Step : 61 | Reward : 12
# Episode : 2 | Step : 62 | Reward : 13
# Episode : 2 | Step : 63 | Reward : 14
# Episode : 2 | Step : 64 | Reward : 14
# Episode : 2 | Step : 65 | Reward : 18
# Episode : 2 | Step : 66 | Reward : 20
# Episode : 2 | Step : 67 | Reward : 23
# Episode : 2 | Step : 68 | Reward : 19
# Episode : 2 | Step : 69 | Reward : 13
# Episode : 2 | Step : 70 | Reward : 13
# Episode : 2 | Step : 71 | Reward : 14
# Episode : 2 | Step : 72 | Reward : 12
# Episode : 2 | Step : 73 | Reward : 16
# Episode : 2 | Step : 74 | Reward : 16
# Episode : 2 | Step : 75 | Reward : 14
# Episode : 2 | Step : 76 | Reward : 16
# Episode : 2 | Step : 77 | Reward : 16
# Episode : 2 | Step : 78 | Reward : 22
# Episode : 2 | Step : 79 | Reward : 21
# Episode : 2 | Step : 80 | Reward : 18
# Episode : 2 | Step : 81 | Reward : 19
# Episode : 2 | Step : 82 | Reward : 13
# Episode : 2 | Step : 83 | Reward : 13
# Episode : 2 | Step : 84 | Reward : 13
# Episode : 2 | Step : 85 | Reward : 15
# Episode : 2 | Step : 86 | Reward : 13
# Episode : 2 | Step : 87 | Reward : 15
# Episode : 2 | Step : 88 | Reward : 13
# Episode : 2 | Step : 89 | Reward : 12
# Episode : 2 | Step : 90 | Reward : 13
# Episode : 2 | Step : 91 | Reward : 12
# Episode : 2 | Step : 92 | Reward : 12
# Episode : 2 | Step : 93 | Reward : 11
# Episode : 2 | Step : 94 | Reward : 11
# Episode : 2 | Step : 95 | Reward : 14
# Episode : 2 | Step : 96 | Reward : 12
# Episode : 2 | Step : 97 | Reward : 11
# Episode : 2 | Step : 98 | Reward : 12
# Episode : 2 | Step : 99 | Reward : 11
# Cube initialized!
# Episode : 3 | Step : 1 | Reward : 15
# Episode : 3 | Step : 2 | Reward : 19
# Episode : 3 | Step : 3 | Reward : 17
# Episode : 3 | Step : 4 | Reward : 18
# Episode : 3 | Step : 5 | Reward : 14
# Episode : 3 | Step : 6 | Reward : 11
# Episode : 3 | Step : 7 | Reward : 8
# Episode : 3 | Step : 8 | Reward : 10
# Episode : 3 | Step : 9 | Reward : 10
# Episode : 3 | Step : 10 | Reward : 10
# Episode : 3 | Step : 11 | Reward : 8
# Episode : 3 | Step : 12 | Reward : 10
# Episode : 3 | Step : 13 | Reward : 12
# Episode : 3 | Step : 14 | Reward : 13
# Episode : 3 | Step : 15 | Reward : 14
# Episode : 3 | Step : 16 | Reward : 13
# Episode : 3 | Step : 17 | Reward : 17
# Episode : 3 | Step : 18 | Reward : 15
# Episode : 3 | Step : 19 | Reward : 15
# Episode : 3 | Step : 20 | Reward : 15
# Episode : 3 | Step : 21 | Reward : 15
# Episode : 3 | Step : 22 | Reward : 16
# Episode : 3 | Step : 23 | Reward : 15
# Episode : 3 | Step : 24 | Reward : 15
# Episode : 3 | Step : 25 | Reward : 14
# Episode : 3 | Step : 26 | Reward : 11
# Episode : 3 | Step : 27 | Reward : 11
# Episode : 3 | Step : 28 | Reward : 12
# Episode : 3 | Step : 29 | Reward : 13
# Episode : 3 | Step : 30 | Reward : 13
# Episode : 3 | Step : 31 | Reward : 13
# Episode : 3 | Step : 32 | Reward : 13
# Episode : 3 | Step : 33 | Reward : 13
# Episode : 3 | Step : 34 | Reward : 13
# Episode : 3 | Step : 35 | Reward : 13
# Episode : 3 | Step : 36 | Reward : 12
# Episode : 3 | Step : 37 | Reward : 13
# Episode : 3 | Step : 38 | Reward : 12
# Episode : 3 | Step : 39 | Reward : 14
# Episode : 3 | Step : 40 | Reward : 14
# Episode : 3 | Step : 41 | Reward : 14
# Episode : 3 | Step : 42 | Reward : 12
# Episode : 3 | Step : 43 | Reward : 14
# Episode : 3 | Step : 44 | Reward : 17
# Episode : 3 | Step : 45 | Reward : 20
# Episode : 3 | Step : 46 | Reward : 19
# Episode : 3 | Step : 47 | Reward : 17
# Episode : 3 | Step : 48 | Reward : 13
# Episode : 3 | Step : 49 | Reward : 11
# Episode : 3 | Step : 50 | Reward : 12
# Episode : 3 | Step : 51 | Reward : 11
# Episode : 3 | Step : 52 | Reward : 10
# Episode : 3 | Step : 53 | Reward : 11
# Episode : 3 | Step : 54 | Reward : 11
# Episode : 3 | Step : 55 | Reward : 11
# Episode : 3 | Step : 56 | Reward : 13
# Episode : 3 | Step : 57 | Reward : 14
# Episode : 3 | Step : 58 | Reward : 13
# Episode : 3 | Step : 59 | Reward : 12
# Episode : 3 | Step : 60 | Reward : 10
# Episode : 3 | Step : 61 | Reward : 12
# Episode : 3 | Step : 62 | Reward : 14
# Episode : 3 | Step : 63 | Reward : 12
# Episode : 3 | Step : 64 | Reward : 13
# Episode : 3 | Step : 65 | Reward : 14
# Episode : 3 | Step : 66 | Reward : 13
# Episode : 3 | Step : 67 | Reward : 15
# Episode : 3 | Step : 68 | Reward : 14
# Episode : 3 | Step : 69 | Reward : 16
# Episode : 3 | Step : 70 | Reward : 12
# Episode : 3 | Step : 71 | Reward : 13
# Episode : 3 | Step : 72 | Reward : 12
# Episode : 3 | Step : 73 | Reward : 10
# Episode : 3 | Step : 74 | Reward : 14
# Episode : 3 | Step : 75 | Reward : 17
# Episode : 3 | Step : 76 | Reward : 14
# Episode : 3 | Step : 77 | Reward : 14
# Episode : 3 | Step : 78 | Reward : 13
# Episode : 3 | Step : 79 | Reward : 10
# Episode : 3 | Step : 80 | Reward : 11
# Episode : 3 | Step : 81 | Reward : 12
# Episode : 3 | Step : 82 | Reward : 12
# Episode : 3 | Step : 83 | Reward : 12
# Episode : 3 | Step : 84 | Reward : 12
# Episode : 3 | Step : 85 | Reward : 11
# Episode : 3 | Step : 86 | Reward : 10
# Episode : 3 | Step : 87 | Reward : 14
# Episode : 3 | Step : 88 | Reward : 15
# Episode : 3 | Step : 89 | Reward : 18
# Episode : 3 | Step : 90 | Reward : 17
# Episode : 3 | Step : 91 | Reward : 18
# Episode : 3 | Step : 92 | Reward : 18
# Episode : 3 | Step : 93 | Reward : 13
# Episode : 3 | Step : 94 | Reward : 9
# Episode : 3 | Step : 95 | Reward : 10
# Episode : 3 | Step : 96 | Reward : 14
# Episode : 3 | Step : 97 | Reward : 12
# Episode : 3 | Step : 98 | Reward : 14
# Episode : 3 | Step : 99 | Reward : 10
# Cube initialized!
# Episode : 4 | Step : 1 | Reward : 13
# Episode : 4 | Step : 2 | Reward : 13
# Episode : 4 | Step : 3 | Reward : 14
# Episode : 4 | Step : 4 | Reward : 12
# Episode : 4 | Step : 5 | Reward : 15
# Episode : 4 | Step : 6 | Reward : 17
# Episode : 4 | Step : 7 | Reward : 13
# Episode : 4 | Step : 8 | Reward : 10
# Episode : 4 | Step : 9 | Reward : 11
# Episode : 4 | Step : 10 | Reward : 11
# Episode : 4 | Step : 11 | Reward : 16
# Episode : 4 | Step : 12 | Reward : 15
# Episode : 4 | Step : 13 | Reward : 18
# Episode : 4 | Step : 14 | Reward : 17
# Episode : 4 | Step : 15 | Reward : 18
# Episode : 4 | Step : 16 | Reward : 14
# Episode : 4 | Step : 17 | Reward : 14
# Episode : 4 | Step : 18 | Reward : 16
# Episode : 4 | Step : 19 | Reward : 18
# Episode : 4 | Step : 20 | Reward : 16
# Episode : 4 | Step : 21 | Reward : 16
# Episode : 4 | Step : 22 | Reward : 13
# Episode : 4 | Step : 23 | Reward : 15
# Episode : 4 | Step : 24 | Reward : 16
# Episode : 4 | Step : 25 | Reward : 16
# Episode : 4 | Step : 26 | Reward : 12
# Episode : 4 | Step : 27 | Reward : 10
# Episode : 4 | Step : 28 | Reward : 12
# Episode : 4 | Step : 29 | Reward : 10
# Episode : 4 | Step : 30 | Reward : 12
# Episode : 4 | Step : 31 | Reward : 12
# Episode : 4 | Step : 32 | Reward : 13
# Episode : 4 | Step : 33 | Reward : 12
# Episode : 4 | Step : 34 | Reward : 12
# Episode : 4 | Step : 35 | Reward : 11
# Episode : 4 | Step : 36 | Reward : 14
# Episode : 4 | Step : 37 | Reward : 12
# Episode : 4 | Step : 38 | Reward : 14
# Episode : 4 | Step : 39 | Reward : 15
# Episode : 4 | Step : 40 | Reward : 17
# Episode : 4 | Step : 41 | Reward : 18
# Episode : 4 | Step : 42 | Reward : 18
# Episode : 4 | Step : 43 | Reward : 15
# Episode : 4 | Step : 44 | Reward : 13
# Episode : 4 | Step : 45 | Reward : 13
# Episode : 4 | Step : 46 | Reward : 13
# Episode : 4 | Step : 47 | Reward : 14
# Episode : 4 | Step : 48 | Reward : 16
# Episode : 4 | Step : 49 | Reward : 13
# Episode : 4 | Step : 50 | Reward : 13
# Episode : 4 | Step : 51 | Reward : 12
# Episode : 4 | Step : 52 | Reward : 13
# Episode : 4 | Step : 53 | Reward : 17
# Episode : 4 | Step : 54 | Reward : 17
# Episode : 4 | Step : 55 | Reward : 11
# Episode : 4 | Step : 56 | Reward : 10
# Episode : 4 | Step : 57 | Reward : 13
# Episode : 4 | Step : 58 | Reward : 14
# Episode : 4 | Step : 59 | Reward : 13
# Episode : 4 | Step : 60 | Reward : 14
# Episode : 4 | Step : 61 | Reward : 13
# Episode : 4 | Step : 62 | Reward : 14
# Episode : 4 | Step : 63 | Reward : 15
# Episode : 4 | Step : 64 | Reward : 15
# Episode : 4 | Step : 65 | Reward : 15
# Episode : 4 | Step : 66 | Reward : 13
# Episode : 4 | Step : 67 | Reward : 16
# Episode : 4 | Step : 68 | Reward : 16
# Episode : 4 | Step : 69 | Reward : 16
# Episode : 4 | Step : 70 | Reward : 13
# Episode : 4 | Step : 71 | Reward : 13
# Episode : 4 | Step : 72 | Reward : 12
# Episode : 4 | Step : 73 | Reward : 14
# Episode : 4 | Step : 74 | Reward : 13
# Episode : 4 | Step : 75 | Reward : 17
# Episode : 4 | Step : 76 | Reward : 13
# Episode : 4 | Step : 77 | Reward : 12
# Episode : 4 | Step : 78 | Reward : 14
# Episode : 4 | Step : 79 | Reward : 14
# Episode : 4 | Step : 80 | Reward : 12
# Episode : 4 | Step : 81 | Reward : 15
# Episode : 4 | Step : 82 | Reward : 17
# Episode : 4 | Step : 83 | Reward : 16
# Episode : 4 | Step : 84 | Reward : 16
# Episode : 4 | Step : 85 | Reward : 14
# Episode : 4 | Step : 86 | Reward : 11
# Episode : 4 | Step : 87 | Reward : 11
# Episode : 4 | Step : 88 | Reward : 13
# Episode : 4 | Step : 89 | Reward : 15
# Episode : 4 | Step : 90 | Reward : 15
# Episode : 4 | Step : 91 | Reward : 13
# Episode : 4 | Step : 92 | Reward : 11
# Episode : 4 | Step : 93 | Reward : 12
# Episode : 4 | Step : 94 | Reward : 10
# Episode : 4 | Step : 95 | Reward : 11
# Episode : 4 | Step : 96 | Reward : 10
# Episode : 4 | Step : 97 | Reward : 12
# Episode : 4 | Step : 98 | Reward : 10
# Episode : 4 | Step : 99 | Reward : 9
# Cube initialized!
# Episode : 5 | Step : 1 | Reward : 18
# Episode : 5 | Step : 2 | Reward : 18
# Episode : 5 | Step : 3 | Reward : 16
# Episode : 5 | Step : 4 | Reward : 16
# Episode : 5 | Step : 5 | Reward : 13
# Episode : 5 | Step : 6 | Reward : 16
# Episode : 5 | Step : 7 | Reward : 19
# Episode : 5 | Step : 8 | Reward : 17
# Episode : 5 | Step : 9 | Reward : 14
# Episode : 5 | Step : 10 | Reward : 14
# Episode : 5 | Step : 11 | Reward : 15
# Episode : 5 | Step : 12 | Reward : 14
# Episode : 5 | Step : 13 | Reward : 15
# Episode : 5 | Step : 14 | Reward : 13
# Episode : 5 | Step : 15 | Reward : 16
# Episode : 5 | Step : 16 | Reward : 17
# Episode : 5 | Step : 17 | Reward : 20
# Episode : 5 | Step : 18 | Reward : 19
# Episode : 5 | Step : 19 | Reward : 16
# Episode : 5 | Step : 20 | Reward : 16
# Episode : 5 | Step : 21 | Reward : 16
# Episode : 5 | Step : 22 | Reward : 20
# Episode : 5 | Step : 23 | Reward : 17
# Episode : 5 | Step : 24 | Reward : 17
# Episode : 5 | Step : 25 | Reward : 15
# Episode : 5 | Step : 26 | Reward : 17
# Episode : 5 | Step : 27 | Reward : 18
# Episode : 5 | Step : 28 | Reward : 16
# Episode : 5 | Step : 29 | Reward : 16
# Episode : 5 | Step : 30 | Reward : 17
# Episode : 5 | Step : 31 | Reward : 13
# Episode : 5 | Step : 32 | Reward : 13
# Episode : 5 | Step : 33 | Reward : 14
# Episode : 5 | Step : 34 | Reward : 12
# Episode : 5 | Step : 35 | Reward : 14
# Episode : 5 | Step : 36 | Reward : 12
# Episode : 5 | Step : 37 | Reward : 15
# Episode : 5 | Step : 38 | Reward : 17
# Episode : 5 | Step : 39 | Reward : 11
# Episode : 5 | Step : 40 | Reward : 16
# Episode : 5 | Step : 41 | Reward : 11
# Episode : 5 | Step : 42 | Reward : 12
# Episode : 5 | Step : 43 | Reward : 17
# Episode : 5 | Step : 44 | Reward : 12
# Episode : 5 | Step : 45 | Reward : 17
# Episode : 5 | Step : 46 | Reward : 14
# Episode : 5 | Step : 47 | Reward : 17
# Episode : 5 | Step : 48 | Reward : 16
# Episode : 5 | Step : 49 | Reward : 13
# Episode : 5 | Step : 50 | Reward : 16
# Episode : 5 | Step : 51 | Reward : 16
# Episode : 5 | Step : 52 | Reward : 16
# Episode : 5 | Step : 53 | Reward : 17
# Episode : 5 | Step : 54 | Reward : 15
# Episode : 5 | Step : 55 | Reward : 15
# Episode : 5 | Step : 56 | Reward : 15
# Episode : 5 | Step : 57 | Reward : 15
# Episode : 5 | Step : 58 | Reward : 14
# Episode : 5 | Step : 59 | Reward : 12
# Episode : 5 | Step : 60 | Reward : 12
# Episode : 5 | Step : 61 | Reward : 14
# Episode : 5 | Step : 62 | Reward : 13
# Episode : 5 | Step : 63 | Reward : 13
# Episode : 5 | Step : 64 | Reward : 14
# Episode : 5 | Step : 65 | Reward : 14
# Episode : 5 | Step : 66 | Reward : 13
# Episode : 5 | Step : 67 | Reward : 15
# Episode : 5 | Step : 68 | Reward : 14
# Episode : 5 | Step : 69 | Reward : 15
# Episode : 5 | Step : 70 | Reward : 14
# Episode : 5 | Step : 71 | Reward : 14
# Episode : 5 | Step : 72 | Reward : 15
# Episode : 5 | Step : 73 | Reward : 15
# Episode : 5 | Step : 74 | Reward : 16
# Episode : 5 | Step : 75 | Reward : 18
# Episode : 5 | Step : 76 | Reward : 16
# Episode : 5 | Step : 77 | Reward : 14
# Episode : 5 | Step : 78 | Reward : 11
# Episode : 5 | Step : 79 | Reward : 13
# Episode : 5 | Step : 80 | Reward : 16
# Episode : 5 | Step : 81 | Reward : 19
# Episode : 5 | Step : 82 | Reward : 16
# Episode : 5 | Step : 83 | Reward : 16
# Episode : 5 | Step : 84 | Reward : 14
# Episode : 5 | Step : 85 | Reward : 15
# Episode : 5 | Step : 86 | Reward : 13
# Episode : 5 | Step : 87 | Reward : 15
# Episode : 5 | Step : 88 | Reward : 13
# Episode : 5 | Step : 89 | Reward : 15
# Episode : 5 | Step : 90 | Reward : 14
# Episode : 5 | Step : 91 | Reward : 15
# Episode : 5 | Step : 92 | Reward : 13
# Episode : 5 | Step : 93 | Reward : 16
# Episode : 5 | Step : 94 | Reward : 16
# Episode : 5 | Step : 95 | Reward : 15
# Episode : 5 | Step : 96 | Reward : 17
# Episode : 5 | Step : 97 | Reward : 15
# Episode : 5 | Step : 98 | Reward : 14
# Episode : 5 | Step : 99 | Reward : 14
# Cube initialized!
# Episode : 6 | Step : 1 | Reward : 14
# Episode : 6 | Step : 2 | Reward : 16
# Episode : 6 | Step : 3 | Reward : 16
# Episode : 6 | Step : 4 | Reward : 17
# Episode : 6 | Step : 5 | Reward : 16
# Episode : 6 | Step : 6 | Reward : 14
# Episode : 6 | Step : 7 | Reward : 17
# Episode : 6 | Step : 8 | Reward : 17
# Episode : 6 | Step : 9 | Reward : 14
# Episode : 6 | Step : 10 | Reward : 14
# Episode : 6 | Step : 11 | Reward : 11
# Episode : 6 | Step : 12 | Reward : 13
# Episode : 6 | Step : 13 | Reward : 14
# Episode : 6 | Step : 14 | Reward : 11
# Episode : 6 | Step : 15 | Reward : 15
# Episode : 6 | Step : 16 | Reward : 11
# Episode : 6 | Step : 17 | Reward : 9
# Episode : 6 | Step : 18 | Reward : 10
# Episode : 6 | Step : 19 | Reward : 10
# Episode : 6 | Step : 20 | Reward : 12
# Episode : 6 | Step : 21 | Reward : 11
# Episode : 6 | Step : 22 | Reward : 13
# Episode : 6 | Step : 23 | Reward : 12
# Episode : 6 | Step : 24 | Reward : 11
# Episode : 6 | Step : 25 | Reward : 12
# Episode : 6 | Step : 26 | Reward : 14
# Episode : 6 | Step : 27 | Reward : 14
# Episode : 6 | Step : 28 | Reward : 14
# Episode : 6 | Step : 29 | Reward : 13
# Episode : 6 | Step : 30 | Reward : 15
# Episode : 6 | Step : 31 | Reward : 13
# Episode : 6 | Step : 32 | Reward : 12
# Episode : 6 | Step : 33 | Reward : 14
# Episode : 6 | Step : 34 | Reward : 13
# Episode : 6 | Step : 35 | Reward : 13
# Episode : 6 | Step : 36 | Reward : 14
# Episode : 6 | Step : 37 | Reward : 13
# Episode : 6 | Step : 38 | Reward : 15
# Episode : 6 | Step : 39 | Reward : 13
# Episode : 6 | Step : 40 | Reward : 13
# Episode : 6 | Step : 41 | Reward : 12
# Episode : 6 | Step : 42 | Reward : 14
# Episode : 6 | Step : 43 | Reward : 11
# Episode : 6 | Step : 44 | Reward : 14
# Episode : 6 | Step : 45 | Reward : 13
# Episode : 6 | Step : 46 | Reward : 14
# Episode : 6 | Step : 47 | Reward : 13
# Episode : 6 | Step : 48 | Reward : 12
# Episode : 6 | Step : 49 | Reward : 10
# Episode : 6 | Step : 50 | Reward : 13
# Episode : 6 | Step : 51 | Reward : 15
# Episode : 6 | Step : 52 | Reward : 12
# Episode : 6 | Step : 53 | Reward : 15
# Episode : 6 | Step : 54 | Reward : 12
# Episode : 6 | Step : 55 | Reward : 12
# Episode : 6 | Step : 56 | Reward : 9
# Episode : 6 | Step : 57 | Reward : 9
# Episode : 6 | Step : 58 | Reward : 10
# Episode : 6 | Step : 59 | Reward : 13
# Episode : 6 | Step : 60 | Reward : 12
# Episode : 6 | Step : 61 | Reward : 11
# Episode : 6 | Step : 62 | Reward : 11
# Episode : 6 | Step : 63 | Reward : 12
# Episode : 6 | Step : 64 | Reward : 14
# Episode : 6 | Step : 65 | Reward : 13
# Episode : 6 | Step : 66 | Reward : 12
# Episode : 6 | Step : 67 | Reward : 15
# Episode : 6 | Step : 68 | Reward : 16
# Episode : 6 | Step : 69 | Reward : 12
# Episode : 6 | Step : 70 | Reward : 14
# Episode : 6 | Step : 71 | Reward : 13
# Episode : 6 | Step : 72 | Reward : 11
# Episode : 6 | Step : 73 | Reward : 13
# Episode : 6 | Step : 74 | Reward : 13
# Episode : 6 | Step : 75 | Reward : 12
# Episode : 6 | Step : 76 | Reward : 13
# Episode : 6 | Step : 77 | Reward : 11
# Episode : 6 | Step : 78 | Reward : 15
# Episode : 6 | Step : 79 | Reward : 12
# Episode : 6 | Step : 80 | Reward : 15
# Episode : 6 | Step : 81 | Reward : 12
# Episode : 6 | Step : 82 | Reward : 14
# Episode : 6 | Step : 83 | Reward : 16
# Episode : 6 | Step : 84 | Reward : 16
# Episode : 6 | Step : 85 | Reward : 13
# Episode : 6 | Step : 86 | Reward : 17
# Episode : 6 | Step : 87 | Reward : 16
# Episode : 6 | Step : 88 | Reward : 15
# Episode : 6 | Step : 89 | Reward : 17
# Episode : 6 | Step : 90 | Reward : 16
# Episode : 6 | Step : 91 | Reward : 18
# Episode : 6 | Step : 92 | Reward : 15
# Episode : 6 | Step : 93 | Reward : 16
# Episode : 6 | Step : 94 | Reward : 17
# Episode : 6 | Step : 95 | Reward : 16
# Episode : 6 | Step : 96 | Reward : 14
# Episode : 6 | Step : 97 | Reward : 11
# Episode : 6 | Step : 98 | Reward : 12
# Episode : 6 | Step : 99 | Reward : 13
# Cube initialized!
# Episode : 7 | Step : 1 | Reward : 15
# Episode : 7 | Step : 2 | Reward : 13
# Episode : 7 | Step : 3 | Reward : 12
# Episode : 7 | Step : 4 | Reward : 10
# Episode : 7 | Step : 5 | Reward : 11
# Episode : 7 | Step : 6 | Reward : 9
# Episode : 7 | Step : 7 | Reward : 9
# Episode : 7 | Step : 8 | Reward : 9
# Episode : 7 | Step : 9 | Reward : 11
# Episode : 7 | Step : 10 | Reward : 9
# Episode : 7 | Step : 11 | Reward : 9
# Episode : 7 | Step : 12 | Reward : 9
# Episode : 7 | Step : 13 | Reward : 13
# Episode : 7 | Step : 14 | Reward : 16
# Episode : 7 | Step : 15 | Reward : 16
# Episode : 7 | Step : 16 | Reward : 13
# Episode : 7 | Step : 17 | Reward : 13
# Episode : 7 | Step : 18 | Reward : 14
# Episode : 7 | Step : 19 | Reward : 13
# Episode : 7 | Step : 20 | Reward : 14
# Episode : 7 | Step : 21 | Reward : 14
# Episode : 7 | Step : 22 | Reward : 12
# Episode : 7 | Step : 23 | Reward : 14
# Episode : 7 | Step : 24 | Reward : 12
# Episode : 7 | Step : 25 | Reward : 12
# Episode : 7 | Step : 26 | Reward : 12
# Episode : 7 | Step : 27 | Reward : 12
# Episode : 7 | Step : 28 | Reward : 11
# Episode : 7 | Step : 29 | Reward : 11
# Episode : 7 | Step : 30 | Reward : 13
# Episode : 7 | Step : 31 | Reward : 12
# Episode : 7 | Step : 32 | Reward : 14
# Episode : 7 | Step : 33 | Reward : 14
# Episode : 7 | Step : 34 | Reward : 15
# Episode : 7 | Step : 35 | Reward : 14
# Episode : 7 | Step : 36 | Reward : 15
# Episode : 7 | Step : 37 | Reward : 14
# Episode : 7 | Step : 38 | Reward : 11
# Episode : 7 | Step : 39 | Reward : 14
# Episode : 7 | Step : 40 | Reward : 12
# Episode : 7 | Step : 41 | Reward : 12
# Episode : 7 | Step : 42 | Reward : 14
# Episode : 7 | Step : 43 | Reward : 16
# Episode : 7 | Step : 44 | Reward : 16
# Episode : 7 | Step : 45 | Reward : 13
# Episode : 7 | Step : 46 | Reward : 12
# Episode : 7 | Step : 47 | Reward : 13
# Episode : 7 | Step : 48 | Reward : 17
# Episode : 7 | Step : 49 | Reward : 14
# Episode : 7 | Step : 50 | Reward : 16
# Episode : 7 | Step : 51 | Reward : 16
# Episode : 7 | Step : 52 | Reward : 15
# Episode : 7 | Step : 53 | Reward : 14
# Episode : 7 | Step : 54 | Reward : 15
# Episode : 7 | Step : 55 | Reward : 12
# Episode : 7 | Step : 56 | Reward : 12
# Episode : 7 | Step : 57 | Reward : 12
# Episode : 7 | Step : 58 | Reward : 14
# Episode : 7 | Step : 59 | Reward : 13
# Episode : 7 | Step : 60 | Reward : 13
# Episode : 7 | Step : 61 | Reward : 11
# Episode : 7 | Step : 62 | Reward : 14
# Episode : 7 | Step : 63 | Reward : 12
# Episode : 7 | Step : 64 | Reward : 14
# Episode : 7 | Step : 65 | Reward : 10
# Episode : 7 | Step : 66 | Reward : 13
# Episode : 7 | Step : 67 | Reward : 17
# Episode : 7 | Step : 68 | Reward : 15
# Episode : 7 | Step : 69 | Reward : 14
# Episode : 7 | Step : 70 | Reward : 14
# Episode : 7 | Step : 71 | Reward : 15
# Episode : 7 | Step : 72 | Reward : 14
# Episode : 7 | Step : 73 | Reward : 14
# Episode : 7 | Step : 74 | Reward : 17
# Episode : 7 | Step : 75 | Reward : 18
# Episode : 7 | Step : 76 | Reward : 14
# Episode : 7 | Step : 77 | Reward : 13
# Episode : 7 | Step : 78 | Reward : 14
# Episode : 7 | Step : 79 | Reward : 12
# Episode : 7 | Step : 80 | Reward : 14
# Episode : 7 | Step : 81 | Reward : 14
# Episode : 7 | Step : 82 | Reward : 13
# Episode : 7 | Step : 83 | Reward : 13
# Episode : 7 | Step : 84 | Reward : 14
# Episode : 7 | Step : 85 | Reward : 15
# Episode : 7 | Step : 86 | Reward : 15
# Episode : 7 | Step : 87 | Reward : 12
# Episode : 7 | Step : 88 | Reward : 9
# Episode : 7 | Step : 89 | Reward : 13
# Episode : 7 | Step : 90 | Reward : 15
# Episode : 7 | Step : 91 | Reward : 12
# Episode : 7 | Step : 92 | Reward : 11
# Episode : 7 | Step : 93 | Reward : 8
# Episode : 7 | Step : 94 | Reward : 9
# Episode : 7 | Step : 95 | Reward : 9
# Episode : 7 | Step : 96 | Reward : 14
# Episode : 7 | Step : 97 | Reward : 9
# Episode : 7 | Step : 98 | Reward : 10
# Episode : 7 | Step : 99 | Reward : 14
# Cube initialized!
# Episode : 8 | Step : 1 | Reward : 10
# Episode : 8 | Step : 2 | Reward : 15
# Episode : 8 | Step : 3 | Reward : 18
# Episode : 8 | Step : 4 | Reward : 21
# Episode : 8 | Step : 5 | Reward : 21
# Episode : 8 | Step : 6 | Reward : 15
# Episode : 8 | Step : 7 | Reward : 16
# Episode : 8 | Step : 8 | Reward : 15
# Episode : 8 | Step : 9 | Reward : 14
# Episode : 8 | Step : 10 | Reward : 17
# Episode : 8 | Step : 11 | Reward : 17
# Episode : 8 | Step : 12 | Reward : 18
# Episode : 8 | Step : 13 | Reward : 20
# Episode : 8 | Step : 14 | Reward : 17
# Episode : 8 | Step : 15 | Reward : 16
# Episode : 8 | Step : 16 | Reward : 11
# Episode : 8 | Step : 17 | Reward : 9
# Episode : 8 | Step : 18 | Reward : 10
# Episode : 8 | Step : 19 | Reward : 12
# Episode : 8 | Step : 20 | Reward : 10
# Episode : 8 | Step : 21 | Reward : 12
# Episode : 8 | Step : 22 | Reward : 13
# Episode : 8 | Step : 23 | Reward : 12
# Episode : 8 | Step : 24 | Reward : 13
# Episode : 8 | Step : 25 | Reward : 11
# Episode : 8 | Step : 26 | Reward : 11
# Episode : 8 | Step : 27 | Reward : 10
# Episode : 8 | Step : 28 | Reward : 9
# Episode : 8 | Step : 29 | Reward : 10
# Episode : 8 | Step : 30 | Reward : 11
# Episode : 8 | Step : 31 | Reward : 9
# Episode : 8 | Step : 32 | Reward : 11
# Episode : 8 | Step : 33 | Reward : 11
# Episode : 8 | Step : 34 | Reward : 14
# Episode : 8 | Step : 35 | Reward : 10
# Episode : 8 | Step : 36 | Reward : 11
# Episode : 8 | Step : 37 | Reward : 12
# Episode : 8 | Step : 38 | Reward : 13
# Episode : 8 | Step : 39 | Reward : 13
# Episode : 8 | Step : 40 | Reward : 13
# Episode : 8 | Step : 41 | Reward : 10
# Episode : 8 | Step : 42 | Reward : 11
# Episode : 8 | Step : 43 | Reward : 12
# Episode : 8 | Step : 44 | Reward : 14
# Episode : 8 | Step : 45 | Reward : 17
# Episode : 8 | Step : 46 | Reward : 16
# Episode : 8 | Step : 47 | Reward : 11
# Episode : 8 | Step : 48 | Reward : 12
# Episode : 8 | Step : 49 | Reward : 11
# Episode : 8 | Step : 50 | Reward : 12
# Episode : 8 | Step : 51 | Reward : 12
# Episode : 8 | Step : 52 | Reward : 13
# Episode : 8 | Step : 53 | Reward : 13
# Episode : 8 | Step : 54 | Reward : 14
# Episode : 8 | Step : 55 | Reward : 18
# Episode : 8 | Step : 56 | Reward : 16
# Episode : 8 | Step : 57 | Reward : 16
# Episode : 8 | Step : 58 | Reward : 17
# Episode : 8 | Step : 59 | Reward : 15
# Episode : 8 | Step : 60 | Reward : 17
# Episode : 8 | Step : 61 | Reward : 19
# Episode : 8 | Step : 62 | Reward : 18
# Episode : 8 | Step : 63 | Reward : 16
# Episode : 8 | Step : 64 | Reward : 16
# Episode : 8 | Step : 65 | Reward : 17
# Episode : 8 | Step : 66 | Reward : 16
# Episode : 8 | Step : 67 | Reward : 14
# Episode : 8 | Step : 68 | Reward : 15
# Episode : 8 | Step : 69 | Reward : 14
# Episode : 8 | Step : 70 | Reward : 15
# Episode : 8 | Step : 71 | Reward : 16
# Episode : 8 | Step : 72 | Reward : 16
# Episode : 8 | Step : 73 | Reward : 17
# Episode : 8 | Step : 74 | Reward : 14
# Episode : 8 | Step : 75 | Reward : 13
# Episode : 8 | Step : 76 | Reward : 14
# Episode : 8 | Step : 77 | Reward : 12
# Episode : 8 | Step : 78 | Reward : 12
# Episode : 8 | Step : 79 | Reward : 12
# Episode : 8 | Step : 80 | Reward : 10
# Episode : 8 | Step : 81 | Reward : 10
# Episode : 8 | Step : 82 | Reward : 13
# Episode : 8 | Step : 83 | Reward : 13
# Episode : 8 | Step : 84 | Reward : 13
# Episode : 8 | Step : 85 | Reward : 13
# Episode : 8 | Step : 86 | Reward : 11
# Episode : 8 | Step : 87 | Reward : 11
# Episode : 8 | Step : 88 | Reward : 9
# Episode : 8 | Step : 89 | Reward : 10
# Episode : 8 | Step : 90 | Reward : 16
# Episode : 8 | Step : 91 | Reward : 11
# Episode : 8 | Step : 92 | Reward : 14
# Episode : 8 | Step : 93 | Reward : 13
# Episode : 8 | Step : 94 | Reward : 14
# Episode : 8 | Step : 95 | Reward : 10
# Episode : 8 | Step : 96 | Reward : 9
# Episode : 8 | Step : 97 | Reward : 12
# Episode : 8 | Step : 98 | Reward : 12
# Episode : 8 | Step : 99 | Reward : 15
# Cube initialized!
# Episode : 9 | Step : 1 | Reward : 14
# Episode : 9 | Step : 2 | Reward : 14
# Episode : 9 | Step : 3 | Reward : 12
# Episode : 9 | Step : 4 | Reward : 15
# Episode : 9 | Step : 5 | Reward : 13
# Episode : 9 | Step : 6 | Reward : 12
# Episode : 9 | Step : 7 | Reward : 15
# Episode : 9 | Step : 8 | Reward : 15
# Episode : 9 | Step : 9 | Reward : 16
# Episode : 9 | Step : 10 | Reward : 12
# Episode : 9 | Step : 11 | Reward : 12
# Episode : 9 | Step : 12 | Reward : 13
# Episode : 9 | Step : 13 | Reward : 14
# Episode : 9 | Step : 14 | Reward : 13
# Episode : 9 | Step : 15 | Reward : 15
# Episode : 9 | Step : 16 | Reward : 13
# Episode : 9 | Step : 17 | Reward : 14
# Episode : 9 | Step : 18 | Reward : 13
# Episode : 9 | Step : 19 | Reward : 18
# Episode : 9 | Step : 20 | Reward : 17
# Episode : 9 | Step : 21 | Reward : 15
# Episode : 9 | Step : 22 | Reward : 13
# Episode : 9 | Step : 23 | Reward : 13
# Episode : 9 | Step : 24 | Reward : 13
# Episode : 9 | Step : 25 | Reward : 15
# Episode : 9 | Step : 26 | Reward : 14
# Episode : 9 | Step : 27 | Reward : 15
# Episode : 9 | Step : 28 | Reward : 17
# Episode : 9 | Step : 29 | Reward : 14
# Episode : 9 | Step : 30 | Reward : 17
# Episode : 9 | Step : 31 | Reward : 16
# Episode : 9 | Step : 32 | Reward : 14
# Episode : 9 | Step : 33 | Reward : 17
# Episode : 9 | Step : 34 | Reward : 18
# Episode : 9 | Step : 35 | Reward : 16
# Episode : 9 | Step : 36 | Reward : 21
# Episode : 9 | Step : 37 | Reward : 18
# Episode : 9 | Step : 38 | Reward : 20
# Episode : 9 | Step : 39 | Reward : 19
# Episode : 9 | Step : 40 | Reward : 18
# Episode : 9 | Step : 41 | Reward : 17
# Episode : 9 | Step : 42 | Reward : 17
# Episode : 9 | Step : 43 | Reward : 17
# Episode : 9 | Step : 44 | Reward : 19
# Episode : 9 | Step : 45 | Reward : 17
# Episode : 9 | Step : 46 | Reward : 16
# Episode : 9 | Step : 47 | Reward : 14
# Episode : 9 | Step : 48 | Reward : 15
# Episode : 9 | Step : 49 | Reward : 14
# Episode : 9 | Step : 50 | Reward : 16
# Episode : 9 | Step : 51 | Reward : 14
# Episode : 9 | Step : 52 | Reward : 12
# Episode : 9 | Step : 53 | Reward : 14
# Episode : 9 | Step : 54 | Reward : 12
# Episode : 9 | Step : 55 | Reward : 12
# Episode : 9 | Step : 56 | Reward : 14
# Episode : 9 | Step : 57 | Reward : 13
# Episode : 9 | Step : 58 | Reward : 11
# Episode : 9 | Step : 59 | Reward : 13
# Episode : 9 | Step : 60 | Reward : 12
# Episode : 9 | Step : 61 | Reward : 18
# Episode : 9 | Step : 62 | Reward : 20
# Episode : 9 | Step : 63 | Reward : 20
# Episode : 9 | Step : 64 | Reward : 18
# Episode : 9 | Step : 65 | Reward : 18
# Episode : 9 | Step : 66 | Reward : 11
# Episode : 9 | Step : 67 | Reward : 11
# Episode : 9 | Step : 68 | Reward : 11
# Episode : 9 | Step : 69 | Reward : 11
# Episode : 9 | Step : 70 | Reward : 10
# Episode : 9 | Step : 71 | Reward : 8
# Episode : 9 | Step : 72 | Reward : 11
# Episode : 9 | Step : 73 | Reward : 11
# Episode : 9 | Step : 74 | Reward : 10
# Episode : 9 | Step : 75 | Reward : 11
# Episode : 9 | Step : 76 | Reward : 9
# Episode : 9 | Step : 77 | Reward : 10
# Episode : 9 | Step : 78 | Reward : 12
# Episode : 9 | Step : 79 | Reward : 10
# Episode : 9 | Step : 80 | Reward : 9
# Episode : 9 | Step : 81 | Reward : 14
# Episode : 9 | Step : 82 | Reward : 15
# Episode : 9 | Step : 83 | Reward : 14
# Episode : 9 | Step : 84 | Reward : 12
# Episode : 9 | Step : 85 | Reward : 14
# Episode : 9 | Step : 86 | Reward : 15
# Episode : 9 | Step : 87 | Reward : 13
# Episode : 9 | Step : 88 | Reward : 11
# Episode : 9 | Step : 89 | Reward : 12
# Episode : 9 | Step : 90 | Reward : 16
# Episode : 9 | Step : 91 | Reward : 15
# Episode : 9 | Step : 92 | Reward : 16
# Episode : 9 | Step : 93 | Reward : 16
# Episode : 9 | Step : 94 | Reward : 14
# Episode : 9 | Step : 95 | Reward : 12
# Episode : 9 | Step : 96 | Reward : 13
# Episode : 9 | Step : 97 | Reward : 15
# Episode : 9 | Step : 98 | Reward : 10
# Episode : 9 | Step : 99 | Reward : 11
# Cube initialized!
# Episode : 10 | Step : 1 | Reward : 18
# Episode : 10 | Step : 2 | Reward : 19
# Episode : 10 | Step : 3 | Reward : 18
# Episode : 10 | Step : 4 | Reward : 20
# Episode : 10 | Step : 5 | Reward : 17
# Episode : 10 | Step : 6 | Reward : 14
# Episode : 10 | Step : 7 | Reward : 12
# Episode : 10 | Step : 8 | Reward : 13
# Episode : 10 | Step : 9 | Reward : 14
# Episode : 10 | Step : 10 | Reward : 15
# Episode : 10 | Step : 11 | Reward : 15
# Episode : 10 | Step : 12 | Reward : 16
# Episode : 10 | Step : 13 | Reward : 15
# Episode : 10 | Step : 14 | Reward : 15
# Episode : 10 | Step : 15 | Reward : 15
# Episode : 10 | Step : 16 | Reward : 18
# Episode : 10 | Step : 17 | Reward : 15
# Episode : 10 | Step : 18 | Reward : 15
# Episode : 10 | Step : 19 | Reward : 14
# Episode : 10 | Step : 20 | Reward : 17
# Episode : 10 | Step : 21 | Reward : 17
# Episode : 10 | Step : 22 | Reward : 15
# Episode : 10 | Step : 23 | Reward : 17
# Episode : 10 | Step : 24 | Reward : 15
# Episode : 10 | Step : 25 | Reward : 11
# Episode : 10 | Step : 26 | Reward : 12
# Episode : 10 | Step : 27 | Reward : 14
# Episode : 10 | Step : 28 | Reward : 12
# Episode : 10 | Step : 29 | Reward : 12
# Episode : 10 | Step : 30 | Reward : 12
# Episode : 10 | Step : 31 | Reward : 13
# Episode : 10 | Step : 32 | Reward : 14
# Episode : 10 | Step : 33 | Reward : 11
# Episode : 10 | Step : 34 | Reward : 13
# Episode : 10 | Step : 35 | Reward : 17
# Episode : 10 | Step : 36 | Reward : 17
# Episode : 10 | Step : 37 | Reward : 17
# Episode : 10 | Step : 38 | Reward : 20
# Episode : 10 | Step : 39 | Reward : 20
# Episode : 10 | Step : 40 | Reward : 19
# Episode : 10 | Step : 41 | Reward : 18
# Episode : 10 | Step : 42 | Reward : 19
# Episode : 10 | Step : 43 | Reward : 18
# Episode : 10 | Step : 44 | Reward : 18
# Episode : 10 | Step : 45 | Reward : 18
# Episode : 10 | Step : 46 | Reward : 16
# Episode : 10 | Step : 47 | Reward : 14
# Episode : 10 | Step : 48 | Reward : 13
# Episode : 10 | Step : 49 | Reward : 14
# Episode : 10 | Step : 50 | Reward : 15
# Episode : 10 | Step : 51 | Reward : 16
# Episode : 10 | Step : 52 | Reward : 13
# Episode : 10 | Step : 53 | Reward : 13
# Episode : 10 | Step : 54 | Reward : 13
# Episode : 10 | Step : 55 | Reward : 13
# Episode : 10 | Step : 56 | Reward : 12
# Episode : 10 | Step : 57 | Reward : 14
# Episode : 10 | Step : 58 | Reward : 15
# Episode : 10 | Step : 59 | Reward : 14
# Episode : 10 | Step : 60 | Reward : 12
# Episode : 10 | Step : 61 | Reward : 14
# Episode : 10 | Step : 62 | Reward : 13
# Episode : 10 | Step : 63 | Reward : 14
# Episode : 10 | Step : 64 | Reward : 13
# Episode : 10 | Step : 65 | Reward : 12
# Episode : 10 | Step : 66 | Reward : 15
# Episode : 10 | Step : 67 | Reward : 11
# Episode : 10 | Step : 68 | Reward : 14
# Episode : 10 | Step : 69 | Reward : 16
# Episode : 10 | Step : 70 | Reward : 14
# Episode : 10 | Step : 71 | Reward : 17
# Episode : 10 | Step : 72 | Reward : 20
# Episode : 10 | Step : 73 | Reward : 13
# Episode : 10 | Step : 74 | Reward : 12
# Episode : 10 | Step : 75 | Reward : 13
# Episode : 10 | Step : 76 | Reward : 12
# Episode : 10 | Step : 77 | Reward : 10
# Episode : 10 | Step : 78 | Reward : 9
# Episode : 10 | Step : 79 | Reward : 8
# Episode : 10 | Step : 80 | Reward : 9
# Episode : 10 | Step : 81 | Reward : 8
# Episode : 10 | Step : 82 | Reward : 9
# Episode : 10 | Step : 83 | Reward : 8
# Episode : 10 | Step : 84 | Reward : 9
# Episode : 10 | Step : 85 | Reward : 11
# Episode : 10 | Step : 86 | Reward : 12
# Episode : 10 | Step : 87 | Reward : 13
# Episode : 10 | Step : 88 | Reward : 12
# Episode : 10 | Step : 89 | Reward : 11
# Episode : 10 | Step : 90 | Reward : 9
# Episode : 10 | Step : 91 | Reward : 11
# Episode : 10 | Step : 92 | Reward : 9
# Episode : 10 | Step : 93 | Reward : 11
# Episode : 10 | Step : 94 | Reward : 15
# Episode : 10 | Step : 95 | Reward : 15
# Episode : 10 | Step : 96 | Reward : 17
# Episode : 10 | Step : 97 | Reward : 17
# Episode : 10 | Step : 98 | Reward : 12
# Episode : 10 | Step : 99 | Reward : 14
# Cube initialized!
# Episode : 11 | Step : 1 | Reward : 12
# Episode : 11 | Step : 2 | Reward : 11
# Episode : 11 | Step : 3 | Reward : 11
# Episode : 11 | Step : 4 | Reward : 10
# Episode : 11 | Step : 5 | Reward : 10
# Episode : 11 | Step : 6 | Reward : 12
# Episode : 11 | Step : 7 | Reward : 10
# Episode : 11 | Step : 8 | Reward : 11
# Episode : 11 | Step : 9 | Reward : 10
# Episode : 11 | Step : 10 | Reward : 11
# Episode : 11 | Step : 11 | Reward : 12
# Episode : 11 | Step : 12 | Reward : 10
# Episode : 11 | Step : 13 | Reward : 13
# Episode : 11 | Step : 14 | Reward : 10
# Episode : 11 | Step : 15 | Reward : 9
# Episode : 11 | Step : 16 | Reward : 9
# Episode : 11 | Step : 17 | Reward : 9
# Episode : 11 | Step : 18 | Reward : 9
# Episode : 11 | Step : 19 | Reward : 9
# Episode : 11 | Step : 20 | Reward : 11
# Episode : 11 | Step : 21 | Reward : 10
# Episode : 11 | Step : 22 | Reward : 12
# Episode : 11 | Step : 23 | Reward : 13
# Episode : 11 | Step : 24 | Reward : 12
# Episode : 11 | Step : 25 | Reward : 10
# Episode : 11 | Step : 26 | Reward : 9
# Episode : 11 | Step : 27 | Reward : 8
# Episode : 11 | Step : 28 | Reward : 12
# Episode : 11 | Step : 29 | Reward : 10
# Episode : 11 | Step : 30 | Reward : 11
# Episode : 11 | Step : 31 | Reward : 9
# Episode : 11 | Step : 32 | Reward : 11
# Episode : 11 | Step : 33 | Reward : 14
# Episode : 11 | Step : 34 | Reward : 13
# Episode : 11 | Step : 35 | Reward : 11
# Episode : 11 | Step : 36 | Reward : 13
# Episode : 11 | Step : 37 | Reward : 13
# Episode : 11 | Step : 38 | Reward : 13
# Episode : 11 | Step : 39 | Reward : 14
# Episode : 11 | Step : 40 | Reward : 12
# Episode : 11 | Step : 41 | Reward : 14
# Episode : 11 | Step : 42 | Reward : 12
# Episode : 11 | Step : 43 | Reward : 10
# Episode : 11 | Step : 44 | Reward : 11
# Episode : 11 | Step : 45 | Reward : 9
# Episode : 11 | Step : 46 | Reward : 11
# Episode : 11 | Step : 47 | Reward : 12
# Episode : 11 | Step : 48 | Reward : 12
# Episode : 11 | Step : 49 | Reward : 12
# Episode : 11 | Step : 50 | Reward : 13
# Episode : 11 | Step : 51 | Reward : 13
# Episode : 11 | Step : 52 | Reward : 8
# Episode : 11 | Step : 53 | Reward : 8
# Episode : 11 | Step : 54 | Reward : 10
# Episode : 11 | Step : 55 | Reward : 10
# Episode : 11 | Step : 56 | Reward : 13
# Episode : 11 | Step : 57 | Reward : 10
# Episode : 11 | Step : 58 | Reward : 9
# Episode : 11 | Step : 59 | Reward : 10
# Episode : 11 | Step : 60 | Reward : 11
# Episode : 11 | Step : 61 | Reward : 8
# Episode : 11 | Step : 62 | Reward : 11
# Episode : 11 | Step : 63 | Reward : 11
# Episode : 11 | Step : 64 | Reward : 14
# Episode : 11 | Step : 65 | Reward : 13
# Episode : 11 | Step : 66 | Reward : 13
# Episode : 11 | Step : 67 | Reward : 13
# Episode : 11 | Step : 68 | Reward : 11
# Episode : 11 | Step : 69 | Reward : 14
# Episode : 11 | Step : 70 | Reward : 15
# Episode : 11 | Step : 71 | Reward : 15
# Episode : 11 | Step : 72 | Reward : 15
# Episode : 11 | Step : 73 | Reward : 14
# Episode : 11 | Step : 74 | Reward : 13
# Episode : 11 | Step : 75 | Reward : 14
# Episode : 11 | Step : 76 | Reward : 18
# Episode : 11 | Step : 77 | Reward : 18
# Episode : 11 | Step : 78 | Reward : 12
# Episode : 11 | Step : 79 | Reward : 12
# Episode : 11 | Step : 80 | Reward : 11
# Episode : 11 | Step : 81 | Reward : 13
# Episode : 11 | Step : 82 | Reward : 13
# Episode : 11 | Step : 83 | Reward : 14
# Episode : 11 | Step : 84 | Reward : 13
# Episode : 11 | Step : 85 | Reward : 15
# Episode : 11 | Step : 86 | Reward : 12
# Episode : 11 | Step : 87 | Reward : 12
# Episode : 11 | Step : 88 | Reward : 12
# Episode : 11 | Step : 89 | Reward : 12
# Episode : 11 | Step : 90 | Reward : 17
# Episode : 11 | Step : 91 | Reward : 12
# Episode : 11 | Step : 92 | Reward : 12
# Episode : 11 | Step : 93 | Reward : 12
# Episode : 11 | Step : 94 | Reward : 11
# Episode : 11 | Step : 95 | Reward : 12
# Episode : 11 | Step : 96 | Reward : 15
# Episode : 11 | Step : 97 | Reward : 16
# Episode : 11 | Step : 98 | Reward : 13
# Episode : 11 | Step : 99 | Reward : 16
# Cube initialized!
# Episode : 12 | Step : 1 | Reward : 10
# Episode : 12 | Step : 2 | Reward : 10
# Episode : 12 | Step : 3 | Reward : 12
# Episode : 12 | Step : 4 | Reward : 11
# Episode : 12 | Step : 5 | Reward : 11
# Episode : 12 | Step : 6 | Reward : 8
# Episode : 12 | Step : 7 | Reward : 11
# Episode : 12 | Step : 8 | Reward : 13
# Episode : 12 | Step : 9 | Reward : 11
# Episode : 12 | Step : 10 | Reward : 10
# Episode : 12 | Step : 11 | Reward : 11
# Episode : 12 | Step : 12 | Reward : 13
# Episode : 12 | Step : 13 | Reward : 14
# Episode : 12 | Step : 14 | Reward : 17
# Episode : 12 | Step : 15 | Reward : 13
# Episode : 12 | Step : 16 | Reward : 10
# Episode : 12 | Step : 17 | Reward : 14
# Episode : 12 | Step : 18 | Reward : 16
# Episode : 12 | Step : 19 | Reward : 14
# Episode : 12 | Step : 20 | Reward : 16
# Episode : 12 | Step : 21 | Reward : 15
# Episode : 12 | Step : 22 | Reward : 14
# Episode : 12 | Step : 23 | Reward : 14
# Episode : 12 | Step : 24 | Reward : 15
# Episode : 12 | Step : 25 | Reward : 16
# Episode : 12 | Step : 26 | Reward : 15
# Episode : 12 | Step : 27 | Reward : 12
# Episode : 12 | Step : 28 | Reward : 13
# Episode : 12 | Step : 29 | Reward : 15
# Episode : 12 | Step : 30 | Reward : 12
# Episode : 12 | Step : 31 | Reward : 15
# Episode : 12 | Step : 32 | Reward : 14
# Episode : 12 | Step : 33 | Reward : 15
# Episode : 12 | Step : 34 | Reward : 14
# Episode : 12 | Step : 35 | Reward : 16
# Episode : 12 | Step : 36 | Reward : 14
# Episode : 12 | Step : 37 | Reward : 16
# Episode : 12 | Step : 38 | Reward : 18
# Episode : 12 | Step : 39 | Reward : 18
# Episode : 12 | Step : 40 | Reward : 21
# Episode : 12 | Step : 41 | Reward : 24
# Episode : 12 | Step : 42 | Reward : 19
# Episode : 12 | Step : 43 | Reward : 14
# Episode : 12 | Step : 44 | Reward : 13
# Episode : 12 | Step : 45 | Reward : 18
# Episode : 12 | Step : 46 | Reward : 14
# Episode : 12 | Step : 47 | Reward : 13
# Episode : 12 | Step : 48 | Reward : 14
# Episode : 12 | Step : 49 | Reward : 13
# Episode : 12 | Step : 50 | Reward : 12
# Episode : 12 | Step : 51 | Reward : 14
# Episode : 12 | Step : 52 | Reward : 16
# Episode : 12 | Step : 53 | Reward : 14
# Episode : 12 | Step : 54 | Reward : 12
# Episode : 12 | Step : 55 | Reward : 10
# Episode : 12 | Step : 56 | Reward : 14
# Episode : 12 | Step : 57 | Reward : 12
# Episode : 12 | Step : 58 | Reward : 14
# Episode : 12 | Step : 59 | Reward : 15
# Episode : 12 | Step : 60 | Reward : 16
# ...
# Episode : 95 | Step : 87 | Reward : 17
# Episode : 95 | Step : 88 | Reward : 17
# Episode : 95 | Step : 89 | Reward : 15
# Episode : 95 | Step : 90 | Reward : 15
# Episode : 95 | Step : 91 | Reward : 15
# Episode : 95 | Step : 92 | Reward : 14
# Episode : 95 | Step : 93 | Reward : 16
# Episode : 95 | Step : 94 | Reward : 14
# Episode : 95 | Step : 95 | Reward : 15
# Episode : 95 | Step : 96 | Reward : 14
# Episode : 95 | Step : 97 | Reward : 13
# Episode : 95 | Step : 98 | Reward : 17
# Episode : 95 | Step : 99 | Reward : 15
# Cube initialized!
# Episode : 96 | Step : 1 | Reward : 13
# Episode : 96 | Step : 2 | Reward : 15
# Episode : 96 | Step : 3 | Reward : 17
# Episode : 96 | Step : 4 | Reward : 12
# Episode : 96 | Step : 5 | Reward : 15
# Episode : 96 | Step : 6 | Reward : 11
# Episode : 96 | Step : 7 | Reward : 16
# Episode : 96 | Step : 8 | Reward : 15
# Episode : 96 | Step : 9 | Reward : 15
# Episode : 96 | Step : 10 | Reward : 15
# Episode : 96 | Step : 11 | Reward : 12
# Episode : 96 | Step : 12 | Reward : 13
# Episode : 96 | Step : 13 | Reward : 12
# Episode : 96 | Step : 14 | Reward : 13
# Episode : 96 | Step : 15 | Reward : 10
# Episode : 96 | Step : 16 | Reward : 10
# Episode : 96 | Step : 17 | Reward : 12
# Episode : 96 | Step : 18 | Reward : 11
# Episode : 96 | Step : 19 | Reward : 12
# Episode : 96 | Step : 20 | Reward : 13
# Episode : 96 | Step : 21 | Reward : 11
# Episode : 96 | Step : 22 | Reward : 11
# Episode : 96 | Step : 23 | Reward : 13
# Episode : 96 | Step : 24 | Reward : 12
# Episode : 96 | Step : 25 | Reward : 11
# Episode : 96 | Step : 26 | Reward : 12
# Episode : 96 | Step : 27 | Reward : 12
# Episode : 96 | Step : 28 | Reward : 12
# Episode : 96 | Step : 29 | Reward : 10
# Episode : 96 | Step : 30 | Reward : 12
# Episode : 96 | Step : 31 | Reward : 11
# Episode : 96 | Step : 32 | Reward : 12
# Episode : 96 | Step : 33 | Reward : 12
# Episode : 96 | Step : 34 | Reward : 11
# Episode : 96 | Step : 35 | Reward : 12
# Episode : 96 | Step : 36 | Reward : 13
# Episode : 96 | Step : 37 | Reward : 14
# Episode : 96 | Step : 38 | Reward : 14
# Episode : 96 | Step : 39 | Reward : 11
# Episode : 96 | Step : 40 | Reward : 11
# Episode : 96 | Step : 41 | Reward : 14
# Episode : 96 | Step : 42 | Reward : 16
# Episode : 96 | Step : 43 | Reward : 14
# Episode : 96 | Step : 44 | Reward : 13
# Episode : 96 | Step : 45 | Reward : 14
# Episode : 96 | Step : 46 | Reward : 14
# Episode : 96 | Step : 47 | Reward : 13
# Episode : 96 | Step : 48 | Reward : 12
# Episode : 96 | Step : 49 | Reward : 10
# Episode : 96 | Step : 50 | Reward : 11
# Episode : 96 | Step : 51 | Reward : 12
# Episode : 96 | Step : 52 | Reward : 13
# Episode : 96 | Step : 53 | Reward : 17
# Episode : 96 | Step : 54 | Reward : 16
# Episode : 96 | Step : 55 | Reward : 15
# Episode : 96 | Step : 56 | Reward : 16
# Episode : 96 | Step : 57 | Reward : 14
# Episode : 96 | Step : 58 | Reward : 15
# Episode : 96 | Step : 59 | Reward : 14
# Episode : 96 | Step : 60 | Reward : 11
# Episode : 96 | Step : 61 | Reward : 11
# Episode : 96 | Step : 62 | Reward : 13
# Episode : 96 | Step : 63 | Reward : 14
# Episode : 96 | Step : 64 | Reward : 12
# Episode : 96 | Step : 65 | Reward : 13
# Episode : 96 | Step : 66 | Reward : 12
# Episode : 96 | Step : 67 | Reward : 14
# Episode : 96 | Step : 68 | Reward : 15
# Episode : 96 | Step : 69 | Reward : 14
# Episode : 96 | Step : 70 | Reward : 16
# Episode : 96 | Step : 71 | Reward : 18
# Episode : 96 | Step : 72 | Reward : 16
# Episode : 96 | Step : 73 | Reward : 16
# Episode : 96 | Step : 74 | Reward : 16
# Episode : 96 | Step : 75 | Reward : 17
# Episode : 96 | Step : 76 | Reward : 17
# Episode : 96 | Step : 77 | Reward : 12
# Episode : 96 | Step : 78 | Reward : 15
# Episode : 96 | Step : 79 | Reward : 16
# Episode : 96 | Step : 80 | Reward : 12
# Episode : 96 | Step : 81 | Reward : 14
# Episode : 96 | Step : 82 | Reward : 11
# Episode : 96 | Step : 83 | Reward : 10
# Episode : 96 | Step : 84 | Reward : 12
# Episode : 96 | Step : 85 | Reward : 10
# Episode : 96 | Step : 86 | Reward : 11
# Episode : 96 | Step : 87 | Reward : 10
# Episode : 96 | Step : 88 | Reward : 12
# Episode : 96 | Step : 89 | Reward : 11
# Episode : 96 | Step : 90 | Reward : 13
# Episode : 96 | Step : 91 | Reward : 13
# Episode : 96 | Step : 92 | Reward : 12
# Episode : 96 | Step : 93 | Reward : 13
# Episode : 96 | Step : 94 | Reward : 18
# Episode : 96 | Step : 95 | Reward : 12
# Episode : 96 | Step : 96 | Reward : 10
# Episode : 96 | Step : 97 | Reward : 9
# Episode : 96 | Step : 98 | Reward : 9
# Episode : 96 | Step : 99 | Reward : 10
# Cube initialized!
# Episode : 97 | Step : 1 | Reward : 18
# Episode : 97 | Step : 2 | Reward : 12
# Episode : 97 | Step : 3 | Reward : 12
# Episode : 97 | Step : 4 | Reward : 9
# Episode : 97 | Step : 5 | Reward : 12
# Episode : 97 | Step : 6 | Reward : 11
# Episode : 97 | Step : 7 | Reward : 11
# Episode : 97 | Step : 8 | Reward : 12
# Episode : 97 | Step : 9 | Reward : 14
# Episode : 97 | Step : 10 | Reward : 14
# Episode : 97 | Step : 11 | Reward : 13
# Episode : 97 | Step : 12 | Reward : 15
# Episode : 97 | Step : 13 | Reward : 20
# Episode : 97 | Step : 14 | Reward : 20
# Episode : 97 | Step : 15 | Reward : 20
# Episode : 97 | Step : 16 | Reward : 20
# Episode : 97 | Step : 17 | Reward : 21
# Episode : 97 | Step : 18 | Reward : 16
# Episode : 97 | Step : 19 | Reward : 16
# Episode : 97 | Step : 20 | Reward : 12
# Episode : 97 | Step : 21 | Reward : 12
# Episode : 97 | Step : 22 | Reward : 15
# Episode : 97 | Step : 23 | Reward : 12
# Episode : 97 | Step : 24 | Reward : 9
# Episode : 97 | Step : 25 | Reward : 11
# Episode : 97 | Step : 26 | Reward : 11
# Episode : 97 | Step : 27 | Reward : 11
# Episode : 97 | Step : 28 | Reward : 11
# Episode : 97 | Step : 29 | Reward : 11
# Episode : 97 | Step : 30 | Reward : 11
# Episode : 97 | Step : 31 | Reward : 15
# Episode : 97 | Step : 32 | Reward : 12
# Episode : 97 | Step : 33 | Reward : 14
# Episode : 97 | Step : 34 | Reward : 15
# Episode : 97 | Step : 35 | Reward : 14
# Episode : 97 | Step : 36 | Reward : 14
# Episode : 97 | Step : 37 | Reward : 17
# Episode : 97 | Step : 38 | Reward : 14
# Episode : 97 | Step : 39 | Reward : 12
# Episode : 97 | Step : 40 | Reward : 14
# Episode : 97 | Step : 41 | Reward : 13
# Episode : 97 | Step : 42 | Reward : 13
# Episode : 97 | Step : 43 | Reward : 11
# Episode : 97 | Step : 44 | Reward : 14
# Episode : 97 | Step : 45 | Reward : 16
# Episode : 97 | Step : 46 | Reward : 14
# Episode : 97 | Step : 47 | Reward : 16
# Episode : 97 | Step : 48 | Reward : 14
# Episode : 97 | Step : 49 | Reward : 13
# Episode : 97 | Step : 50 | Reward : 12
# Episode : 97 | Step : 51 | Reward : 12
# Episode : 97 | Step : 52 | Reward : 13
# Episode : 97 | Step : 53 | Reward : 12
# Episode : 97 | Step : 54 | Reward : 12
# Episode : 97 | Step : 55 | Reward : 13
# Episode : 97 | Step : 56 | Reward : 13
# Episode : 97 | Step : 57 | Reward : 13
# Episode : 97 | Step : 58 | Reward : 13
# Episode : 97 | Step : 59 | Reward : 16
# Episode : 97 | Step : 60 | Reward : 17
# Episode : 97 | Step : 61 | Reward : 16
# Episode : 97 | Step : 62 | Reward : 18
# Episode : 97 | Step : 63 | Reward : 15
# Episode : 97 | Step : 64 | Reward : 11
# Episode : 97 | Step : 65 | Reward : 12
# Episode : 97 | Step : 66 | Reward : 13
# Episode : 97 | Step : 67 | Reward : 14
# Episode : 97 | Step : 68 | Reward : 15
# Episode : 97 | Step : 69 | Reward : 14
# Episode : 97 | Step : 70 | Reward : 14
# Episode : 97 | Step : 71 | Reward : 14
# Episode : 97 | Step : 72 | Reward : 14
# Episode : 97 | Step : 73 | Reward : 14
# Episode : 97 | Step : 74 | Reward : 15
# Episode : 97 | Step : 75 | Reward : 16
# Episode : 97 | Step : 76 | Reward : 15
# Episode : 97 | Step : 77 | Reward : 15
# Episode : 97 | Step : 78 | Reward : 16
# Episode : 97 | Step : 79 | Reward : 16
# Episode : 97 | Step : 80 | Reward : 16
# Episode : 97 | Step : 81 | Reward : 16
# Episode : 97 | Step : 82 | Reward : 15
# Episode : 97 | Step : 83 | Reward : 16
# Episode : 97 | Step : 84 | Reward : 13
# Episode : 97 | Step : 85 | Reward : 12
# Episode : 97 | Step : 86 | Reward : 11
# Episode : 97 | Step : 87 | Reward : 12
# Episode : 97 | Step : 88 | Reward : 11
# Episode : 97 | Step : 89 | Reward : 12
# Episode : 97 | Step : 90 | Reward : 13
# Episode : 97 | Step : 91 | Reward : 12
# Episode : 97 | Step : 92 | Reward : 14
# Episode : 97 | Step : 93 | Reward : 15
# Episode : 97 | Step : 94 | Reward : 15
# Episode : 97 | Step : 95 | Reward : 15
# Episode : 97 | Step : 96 | Reward : 15
# Episode : 97 | Step : 97 | Reward : 16
# Episode : 97 | Step : 98 | Reward : 17
# Episode : 97 | Step : 99 | Reward : 16
# Cube initialized!
# Episode : 98 | Step : 1 | Reward : 17
# Episode : 98 | Step : 2 | Reward : 14
# Episode : 98 | Step : 3 | Reward : 17
# Episode : 98 | Step : 4 | Reward : 16
# Episode : 98 | Step : 5 | Reward : 16
# Episode : 98 | Step : 6 | Reward : 18
# Episode : 98 | Step : 7 | Reward : 16
# Episode : 98 | Step : 8 | Reward : 16
# Episode : 98 | Step : 9 | Reward : 18
# Episode : 98 | Step : 10 | Reward : 18
# Episode : 98 | Step : 11 | Reward : 13
# Episode : 98 | Step : 12 | Reward : 17
# Episode : 98 | Step : 13 | Reward : 16
# Episode : 98 | Step : 14 | Reward : 16
# Episode : 98 | Step : 15 | Reward : 15
# Episode : 98 | Step : 16 | Reward : 14
# Episode : 98 | Step : 17 | Reward : 14
# Episode : 98 | Step : 18 | Reward : 14
# Episode : 98 | Step : 19 | Reward : 17
# Episode : 98 | Step : 20 | Reward : 14
# Episode : 98 | Step : 21 | Reward : 14
# Episode : 98 | Step : 22 | Reward : 11
# Episode : 98 | Step : 23 | Reward : 11
# Episode : 98 | Step : 24 | Reward : 14
# Episode : 98 | Step : 25 | Reward : 13
# Episode : 98 | Step : 26 | Reward : 16
# Episode : 98 | Step : 27 | Reward : 12
# Episode : 98 | Step : 28 | Reward : 12
# Episode : 98 | Step : 29 | Reward : 14
# Episode : 98 | Step : 30 | Reward : 12
# Episode : 98 | Step : 31 | Reward : 14
# Episode : 98 | Step : 32 | Reward : 14
# Episode : 98 | Step : 33 | Reward : 13
# Episode : 98 | Step : 34 | Reward : 14
# Episode : 98 | Step : 35 | Reward : 14
# Episode : 98 | Step : 36 | Reward : 16
# Episode : 98 | Step : 37 | Reward : 16
# Episode : 98 | Step : 38 | Reward : 14
# Episode : 98 | Step : 39 | Reward : 14
# Episode : 98 | Step : 40 | Reward : 10
# Episode : 98 | Step : 41 | Reward : 11
# Episode : 98 | Step : 42 | Reward : 12
# Episode : 98 | Step : 43 | Reward : 11
# Episode : 98 | Step : 44 | Reward : 10
# Episode : 98 | Step : 45 | Reward : 13
# Episode : 98 | Step : 46 | Reward : 14
# Episode : 98 | Step : 47 | Reward : 15
# Episode : 98 | Step : 48 | Reward : 16
# Episode : 98 | Step : 49 | Reward : 14
# Episode : 98 | Step : 50 | Reward : 13
# Episode : 98 | Step : 51 | Reward : 12
# Episode : 98 | Step : 52 | Reward : 11
# Episode : 98 | Step : 53 | Reward : 12
# Episode : 98 | Step : 54 | Reward : 11
# Episode : 98 | Step : 55 | Reward : 10
# Episode : 98 | Step : 56 | Reward : 13
# Episode : 98 | Step : 57 | Reward : 13
# Episode : 98 | Step : 58 | Reward : 14
# Episode : 98 | Step : 59 | Reward : 13
# Episode : 98 | Step : 60 | Reward : 14
# Episode : 98 | Step : 61 | Reward : 13
# Episode : 98 | Step : 62 | Reward : 13
# Episode : 98 | Step : 63 | Reward : 12
# Episode : 98 | Step : 64 | Reward : 13
# Episode : 98 | Step : 65 | Reward : 12
# Episode : 98 | Step : 66 | Reward : 13
# Episode : 98 | Step : 67 | Reward : 16
# Episode : 98 | Step : 68 | Reward : 14
# Episode : 98 | Step : 69 | Reward : 17
# Episode : 98 | Step : 70 | Reward : 15
# Episode : 98 | Step : 71 | Reward : 14
# Episode : 98 | Step : 72 | Reward : 15
# Episode : 98 | Step : 73 | Reward : 14
# Episode : 98 | Step : 74 | Reward : 11
# Episode : 98 | Step : 75 | Reward : 12
# Episode : 98 | Step : 76 | Reward : 11
# Episode : 98 | Step : 77 | Reward : 13
# Episode : 98 | Step : 78 | Reward : 11
# Episode : 98 | Step : 79 | Reward : 11
# Episode : 98 | Step : 80 | Reward : 11
# Episode : 98 | Step : 81 | Reward : 12
# Episode : 98 | Step : 82 | Reward : 11
# Episode : 98 | Step : 83 | Reward : 12
# Episode : 98 | Step : 84 | Reward : 13
# Episode : 98 | Step : 85 | Reward : 12
# Episode : 98 | Step : 86 | Reward : 13
# Episode : 98 | Step : 87 | Reward : 12
# Episode : 98 | Step : 88 | Reward : 14
# Episode : 98 | Step : 89 | Reward : 12
# Episode : 98 | Step : 90 | Reward : 14
# Episode : 98 | Step : 91 | Reward : 14
# Episode : 98 | Step : 92 | Reward : 16
# Episode : 98 | Step : 93 | Reward : 17
# Episode : 98 | Step : 94 | Reward : 12
# Episode : 98 | Step : 95 | Reward : 13
# Episode : 98 | Step : 96 | Reward : 15
# Episode : 98 | Step : 97 | Reward : 13
# Episode : 98 | Step : 98 | Reward : 11
# Episode : 98 | Step : 99 | Reward : 11
# Cube initialized!
# Episode : 99 | Step : 1 | Reward : 18
# Episode : 99 | Step : 2 | Reward : 16
# Episode : 99 | Step : 3 | Reward : 19
# Episode : 99 | Step : 4 | Reward : 24
# Episode : 99 | Step : 5 | Reward : 19
# Episode : 99 | Step : 6 | Reward : 19
# Episode : 99 | Step : 7 | Reward : 15
# Episode : 99 | Step : 8 | Reward : 19
# Episode : 99 | Step : 9 | Reward : 14
# Episode : 99 | Step : 10 | Reward : 12
# Episode : 99 | Step : 11 | Reward : 15
# Episode : 99 | Step : 12 | Reward : 15
# Episode : 99 | Step : 13 | Reward : 17
# Episode : 99 | Step : 14 | Reward : 16
# Episode : 99 | Step : 15 | Reward : 13
# Episode : 99 | Step : 16 | Reward : 16
# Episode : 99 | Step : 17 | Reward : 18
# Episode : 99 | Step : 18 | Reward : 15
# Episode : 99 | Step : 19 | Reward : 10
# Episode : 99 | Step : 20 | Reward : 9
# Episode : 99 | Step : 21 | Reward : 10
# Episode : 99 | Step : 22 | Reward : 14
# Episode : 99 | Step : 23 | Reward : 16
# Episode : 99 | Step : 24 | Reward : 13
# Episode : 99 | Step : 25 | Reward : 12
# Episode : 99 | Step : 26 | Reward : 13
# Episode : 99 | Step : 27 | Reward : 12
# Episode : 99 | Step : 28 | Reward : 14
# Episode : 99 | Step : 29 | Reward : 15
# Episode : 99 | Step : 30 | Reward : 13
# Episode : 99 | Step : 31 | Reward : 16
# Episode : 99 | Step : 32 | Reward : 15
# Episode : 99 | Step : 33 | Reward : 12
# Episode : 99 | Step : 34 | Reward : 12
# Episode : 99 | Step : 35 | Reward : 15
# Episode : 99 | Step : 36 | Reward : 21
# Episode : 99 | Step : 37 | Reward : 18
# Episode : 99 | Step : 38 | Reward : 25
# Episode : 99 | Step : 39 | Reward : 23
# Episode : 99 | Step : 40 | Reward : 16
# Episode : 99 | Step : 41 | Reward : 23
# Episode : 99 | Step : 42 | Reward : 19
# Episode : 99 | Step : 43 | Reward : 13
# Episode : 99 | Step : 44 | Reward : 16
# Episode : 99 | Step : 45 | Reward : 12
# Episode : 99 | Step : 46 | Reward : 14
# Episode : 99 | Step : 47 | Reward : 13
# Episode : 99 | Step : 48 | Reward : 11
# Episode : 99 | Step : 49 | Reward : 13
# Episode : 99 | Step : 50 | Reward : 17
# Episode : 99 | Step : 51 | Reward : 14
# Episode : 99 | Step : 52 | Reward : 13
# Episode : 99 | Step : 53 | Reward : 10
# Episode : 99 | Step : 54 | Reward : 13
# Episode : 99 | Step : 55 | Reward : 10
# Episode : 99 | Step : 56 | Reward : 13
# Episode : 99 | Step : 57 | Reward : 13
# Episode : 99 | Step : 58 | Reward : 13
# Episode : 99 | Step : 59 | Reward : 12
# Episode : 99 | Step : 60 | Reward : 11
# Episode : 99 | Step : 61 | Reward : 12
# Episode : 99 | Step : 62 | Reward : 15
# Episode : 99 | Step : 63 | Reward : 16
# Episode : 99 | Step : 64 | Reward : 15
# Episode : 99 | Step : 65 | Reward : 13
# Episode : 99 | Step : 66 | Reward : 18
# Episode : 99 | Step : 67 | Reward : 14
# Episode : 99 | Step : 68 | Reward : 16
# Episode : 99 | Step : 69 | Reward : 14
# Episode : 99 | Step : 70 | Reward : 16
# Episode : 99 | Step : 71 | Reward : 14
# Episode : 99 | Step : 72 | Reward : 14
# Episode : 99 | Step : 73 | Reward : 16
# Episode : 99 | Step : 74 | Reward : 14
# Episode : 99 | Step : 75 | Reward : 16
# Episode : 99 | Step : 76 | Reward : 12
# Episode : 99 | Step : 77 | Reward : 12
# Episode : 99 | Step : 78 | Reward : 12
# Episode : 99 | Step : 79 | Reward : 12
# Episode : 99 | Step : 80 | Reward : 13
# Episode : 99 | Step : 81 | Reward : 11
# Episode : 99 | Step : 82 | Reward : 10
# Episode : 99 | Step : 83 | Reward : 11
# Episode : 99 | Step : 84 | Reward : 11
# Episode : 99 | Step : 85 | Reward : 13
# Episode : 99 | Step : 86 | Reward : 16
# Episode : 99 | Step : 87 | Reward : 13
# Episode : 99 | Step : 88 | Reward : 15
# Episode : 99 | Step : 89 | Reward : 17
# Episode : 99 | Step : 90 | Reward : 16
# Episode : 99 | Step : 91 | Reward : 17
# Episode : 99 | Step : 92 | Reward : 14
# Episode : 99 | Step : 93 | Reward : 14
# Episode : 99 | Step : 94 | Reward : 19
# Episode : 99 | Step : 95 | Reward : 16
# Episode : 99 | Step : 96 | Reward : 15
# Episode : 99 | Step : 97 | Reward : 16
# Episode : 99 | Step : 98 | Reward : 14
# Episode : 99 | Step : 99 | Reward : 12
